# %%
import numpy as np
from collections import namedtuple
import sys
from typing import List, Tuple, Dict, Set, Union
import torch
import torch.nn as nn
import torch.nn.utils
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence
from nltk import word_tokenize
import pickle
from model_embeddings import ModelEmbeddings
from evaluator import Evaluator
from vocab import Vocab, VocabEntry
from utils import read_corpus, pad_sents, batch_iter

# %%
definitions = []
unparsed_definition = []
words = []
#src_sents = read_corpus('../data/data_train_definitions.txt')

# %%
# with open('../data/data_train_words.txt') as f:
#     words += f.read().splitlines()
    
# with open('../data/data_train_definitions.txt') as f:
#     unparsed_definition += f.read().splitlines()
#     definitions += [word_tokenize(a) for a in unparsed_definition]

# training_data = [(definitions[i], words[i]) for i in range(len(words))]

# %%
train, valid, test = pickle.load(open("../data/train_valid_test.data", "rb"))

unparsed_definition = [t[1] for t in train]
definitions = [word_tokenize(a) for a in unparsed_definition]
words = [t[0] for t in train]

# %%
eval = Evaluator()
fasttext_dict = eval.load_vectors(fname ="../data/wiki-news-300d-1M-subword.vec", max_line = 10000000)
sub_fasttext_dict = {}

for i in range(len(words)-1, -1, -1):
    if words[i] not in fasttext_dict:
        print(words[i])
        words.pop(i)
        definitions.pop(i)
    else:
        sub_fasttext_dict[words[i]] = fasttext_dict[words[i]]
        
high_freq_dict = eval.load_vectors(fname ="../data/wiki-news-300d-1M-subword.vec", max_line = 30000)
sub_fasttext_dict.update(high_freq_dict)
# Out:
# 999994it [01:04, 15529.06it/s]
# metachrosis
# sullage
# spited
# aleurometer
# focalizes
# podobranch
# heterocera
# Curietherapy
# periwigged
# constrainable
# yojan
# boroglyceride
# testaceology
# pacificator
# harmotome
# sudoral
# erubescence
# deadworks
# zoochlorella
# disharmonize
# munite
# theanthropism
# cerebripetal
# herpetism
# substantiveness
# intercolumniation
# locomotivity
# waterbury
# malanders
# branks
# inosculating
# philomathic
# richnesses
# shaggily
# nidification
# scrubbier
# stibic
# prorogues
# thirlage
# clickings
# godship
# dysosmia
# letterheadings
# misdone
# salicylal
# prognosticable
# pitpan
# platinic
# reluctation
# saccharic
# Suctoria
# hoarhound
# parasita
# moonlighter
# gorgoneion
# poolers
# digitorium
# oaves
# inalienableness
# dizz
# decandrous
# santees
# greengroceries
# inthralled
# tropidine
# spellful
# lenticellate
# whencesoever
# jalapin
# macropodous
# lockkeeper
# lightsomely
# resail
# achromatous
# synclinorium
# tenuated
# twaites
# embaying
# perkinism
# siphonage
# epicolic
# basifier
# yeomanly
# ecardines
# rationalness
# gunflint
# vociferation
# pyorrhoea
# hoves
# sternutative
# quaigh
# coopered
# measle
# noddings
# ibsenian
# ditchers
# digamist
# procoelia
# quadras
# rattoon
# lyrate
# ammoniuria
# merchantry
# mismanager
# motleyed
# hebraically
# cypraea
# remast
# jungians
# adscititious
# palmigrade
# thrombocyte
# phonolites
# caryatic
# austereness
# virulented
# baculite
# amandine
# glitterings
# gannister
# cohobation
# varvel
# electrolyzable
# globularity
# thermovoltaic
# biarticulate
# chemisette
# reverer
# brailing
# precompiling
# kelling
# proceleusmatic
# ailette
# isatin
# damasse
# alexipyretic
# pauperizing
# postcommissure
# sponsion
# fowers
# tinnier
# worlder
# marginate
# keratose
# pottiest
# overbidden
# eightscore
# declivous
# cortland
# Ctenocephalides
# demonocracy
# mump
# ziega
# platycnemism
# intersticed
# ditroite
# bestridden
# reguline
# displenish
# chirurgic
# esophagoscope
# dermatography
# synaxis
# pluff
# eolotropic
# banshie
# redargued
# extractiform
# mammock
# telpher
# dialogize
# trophi
# reversioner
# vestmental
# cadgy
# catadrome
# astylar
# gelatiniferous
# lacerative
# anacathartic
# cranage
# exsect
# fabians
# metacentrics
# ungainliest
# discombobulates
# ammonified
# Clifts
# procreant
# cladophyll
# tyrannicidal
# dyslexias
# lupulin
# callots
# opobalsamum
# hamstringed
# treatiser
# empoison
# parachordal
# abrader
# piffles
# electropathy
# lactobutyrometer
# tribometer
# mesitylene
# Elviscerate
# abstinences
# alibiing
# wrightine
# bottlefeed
# canonship
# blithesome
# coapt
# paltock
# propeptone
# copaiva
# embay
# revengefully
# ablegate
# deuteropathic
# roadhog
# purpuriparous
# rigidulous
# duluth
# dishtowels
# confusables
# kananga
# cisted
# lacer
# bogwood
# irrupted
# entoplastra
# cxl
# idorgan
# snotter
# ostrogothic
# coacting
# obsolesces
# stour
# endosmosis
# hortensial
# issuably
# myristin
# crossjack
# enswathe
# cornier
# asynergic
# muley
# nonylene
# brittlely
# nainsook
# truckles
# levigate
# polythalamous
# sputterings
# endamagement
# akaryocyte
# laredo
# retrogresses
# sniffler
# tabularizing
# murrayin
# tryptone
# fairylike
# creaser
# cantillating
# Heyrovsky
# Pygopodidae
# bemocks
# favorer
# gymnoblastea
# unswear
# cofferer
# offscouring
# pathogeny
# fricasseed
# sideslipped
# downwarped
# laciniolate
# prickings
# interpenetrates
# protophyte
# permanencies
# aurocyanide
# raglans
# pithecoid
# ubiquitarian
# monospermal
# superexcellence
# embar
# impartment
# lenticula
# sludged
# lithophotography
# mutteringly
# hibernacle
# stipular
# antisepticizing
# eloge
# dictamnus
# displuming
# disseizee
# cholerics
# privateered
# endameba
# internuncial
# semaphored
# hydranth
# pressurage
# lithargyrum
# neuroplasty
# thecaphore
# crunode
# catechistic
# xanthoxylene
# furfuraceous
# lithodomous
# laryngotomy
# holloa
# undertenancy
# inertials
# Pomatomidae
# savvies
# accentuable
# Lymtudor
# disagreer
# commoved
# forgivenesses
# disthene
# reproofed
# viscountesses
# balker
# nundinal
# becomingness
# hemisected
# halfpennys
# linecut
# tuitioning
# heptylene
# undried
# gurlet
# mazdean
# alienor
# scopulas
# teetee
# frithstool
# etiolate
# rabbets
# phthisical
# disorderlies
# shoeshining
# brevirostrate
# copartneries
# outcrying
# intitule
# adagial
# solarised
# bakeapple
# sarplar
# gorgings
# outdweller
# agamous
# jaculating
# blindings
# fangless
# gagger
# traumatophobia
# literalization
# nummulites
# polymorphemic
# eudaemonics
# fraised
# incognizable
# scuttering
# tribometer
# ambulator
# griseous
# conqueress
# bedimming
# agonistics
# misconceiver
# epichorial
# epizoan
# wolfling
# chromidrosis
# heptandrian
# glibber
# catadioptrics
# circumventive
# smaragdine
# omniparity
# refrangible
# chirographer
# versemonger
# righten
# bedecking
# parament
# circumflexing
# betrothing
# shroffage
# soboles
# locellate
# linnaeite
# hyetograph
# bootlicks
# adiaphorist
# luminesces
# polybasic
# ginzo
# nullipore
# dicalcic
# consubstantially
# Fucaceae
# bounteously
# acetification
# univalve
# redemise
# Castalians
# misdoubts
# pumiced
# gunlock
# reaggregating
# vigoroso
# phormium
# stromatology
# reposits
# paxwax
# pseudoblepsis
# discobolus
# apotome
# demilancer
# koklass
# desudation
# sleaving
# monocrotic
# unmethodical
# junketings
# sudor
# undersetting
# convergency
# raddling
# hydrometrical
# isopogonous
# motorcaded
# manway
# shorl
# diachylon
# chloralum
# sipe
# shoad
# scourings
# birdcall
# halse
# fiorite
# inadequation
# tonguelet
# creance
# hitchings
# felloes
# isochimene
# outmeasure
# canulating
# decastyle
# jehovistic
# synaeresis
# tenanting
# naphthalenic
# stived
# monandrian
# congruously
# cumulonimbi
# myograph
# pyrognostics
# mensurableness
# habilatory
# cinefaction
# tastily
# landsturm
# amusable
# chauffeuse
# phyllomorphosis
# obtruder
# turpeth
# oxysalt
# porcellaneous
# doeskin
# syruped
# hardhack
# chummier
# oophoritis
# longinquity
# fascet
# etiolating
# rhamphorhynchus
# candite
# semeiology
# touchings
# valeramide
# immetrical
# diablerie
# marver
# distinguishedly
# wardmote
# creaseless
# vitrescence
# steelmen
# phytography
# pinniform
# misconducting
# hoopskirt
# larker
# heartshaped
# survivorships
# chasmed
# echauguette
# sublating
# orbitosphenoid
# kotowed
# bilestone
# depolarises
# walty
# disgustful
# orbiculate
# bambinos
# whirlbone
# underlet
# blowzier
# aurify
# bluffly
# pygopod
# nidorous
# dovekie
# rubian
# englishing
# wakener
# acaudal
# synchroneity
# unifacial
# favourableness
# maltin
# pediculus
# recaption
# homophylic
# detribalized
# sashoon
# empyreuma
# naseberry
# stylometer
# cervices
# quiddle
# achlamydeous
# absolvable
# marline
# wrigglings
# uprooter
# Occidentalise
# prudhomme
# assertable
# prescinds
# vacillant
# overdresses
# resinic
# deputable
# apert
# pendulate
# sprightful
# huzza
# fingerbreadth
# glycin
# lockstitching
# bilbo
# eductor
# rosita
# brassbound
# regrater
# backpiece
# basidial
# craniognomy
# hepatite
# ozonometry
# egger
# pullicate
# bevelment
# perigynous
# papula
# spoonworm
# owings
# cyanophyll
# arithmancy
# falsism
# invaliding
# oneirocritic
# spued
# Sadduceeism
# ironbound
# strewment
# cotarnine
# dispope
# wiriest
# palmature
# decorticates
# incrassate
# flavol
# whiningly
# magnetical
# higgler
# sulphuretted
# agami
# lightermen
# aristulate
# ruche
# goldbricking
# chalazas
# jungians
# predicables
# capableness
# epaulement
# puddening
# pantomimical
# titanous
# polybutylenes
# featheredge
# deducibleness
# bivium
# pseudopolyps
# dammara
# sensualization
# lankly
# groomings
# flasket
# bottlefeeds
# cephalaspis
# incommutability
# chargings
# snuggery
# proportionating
# airwoman
# buttonhook
# besprinkled
# gropingly
# deloul
# sperrylite
# swobs
# muscae
# slendering
# misgives
# booboisie
# unduke
# peccavi
# neologistical
# stipendiaries
# flickeringly
# underquotes
# viscosimetry
# astringently
# stichometrical
# ariose
# pauser
# Spratts
# moodys
# beakhead
# pendicle
# baptizable
# axinite
# clarinettists
# tabler
# keeve
# accoy
# impeditive
# yestreen
# cnidoblast
# caustical
# fossulate
# bonapartist
# ichnological
# benthamism
# stonebrash
# pearlash
# galvanography
# intemerateness
# monogyny
# opisthognathous
# gaylussite
# combatable
# convocational
# epiglottises
# piperaceous
# outsing
# gyrencephala
# helicin
# acockbill
# downcome
# cerebrums
# varanus
# lardaceous
# desirousness
# prelatize
# mercaptal
# infallibleness
# scanter
# petiolulate
# supposeer
# dactylar
# protending
# thoracocentesis
# Ismaelian
# enwall
# omnivora
# valeric
# outfly
# deceivableness
# mesopodial
# ceratosaurus
# machinal
# sleeks
# pseudoscopic
# waveson
# epistyle
# opinionist
# outsentry
# unrenewable
# hydrogalvanic
# promorphology
# sphaeridia
# stoniest
# chansonnettes
# xylic
# oppugned
# bewrayed
# torsi
# bondmaids
# schnorrer
# hoveling
# irrespirable
# eyet
# blindworm
# elain
# legist
# interradial
# oidium
# jarvey
# traject
# cognominal
# sextans
# blackcoat
# reprieving
# calendarial
# candelilla
# geognostical
# mecholyl
# disquisitional
# aepyornis
# stockish
# reglet
# bumpings
# liard
# anlace
# assarts
# tricentenary
# Lungworts
# claustra
# outcried
# prelusive
# superterranean
# epipteric
# kalmias
# cerography
# orthospermous
# abolisher
# sporogenesis
# paragnathous
# dittoed
# unguiform
# lapps
# anthropophagus
# impregnant
# bushhammer
# howards
# zoologies
# limonin
# lorette
# wheelless
# dunbird
# inosculate
# youngstown
# roastings
# omahas
# mellowest
# homopteran
# wharfed
# galvanist
# solvates
# slumbrous
# stearns
# aerometric
# siss
# amylolytic
# demilitarizes
# gripings
# circumspective
# syllogise
# crotcheted
# leeringly
# repositor
# orthodoxness
# exigible
# whitehorse
# serrulated
# denationalise
# tungstic
# cholecystotomy
# calcarated
# deflexion
# myriare
# omened
# obversion
# chthonophagy
# blastodermatic
# pterygoquadrate
# marmorate
# thermosystaltic
# presagement
# Hebraize
# overclouding
# simpai
# sporosac
# arthrodial
# bradawl
# schematizing
# setwall
# immingling
# asomatous
# dipteral
# synthetised
# hydrophane
# kneebrush
# tartramide
# amalgamative
# siderites
# dekastere
# disseized
# laborsome
# adjustables
# berme
# torturings
# greyly
# meconate
# anagogics
# cruorin
# electrotonus
# blain
# linne
# impecuniousness
# ranchmen
# fortitudes
# thymy
# semicolumn
# malefaction
# underfilling
# krang
# phanerogamia
# burnets
# marshalship
# liquation
# emption
# decolouring
# flexings
# radiographing
# colocalized
# melilot
# intrusts
# agrology
# creakings
# thecodontia
# atwirl
# glazy
# atting
# zoetropes
# dragonish
# detorsion
# peptonize
# smouch
# hammermen
# sartor
# lixiviating
# sparoid
# haidingerite
# tocororo
# depraver
# scrabbly
# palindromist
# backsight
# justle
# shmucks
# ganning
# polyiodide
# discolith
# nawabi
# euonymin
# Laputans
# palmatisect
# bilaminar
# arbuscle
# technicist
# subcelestial
# jackstone
# emancipative
# superjacent
# haematocolpos
# catachrestical
# pseudovary
# amatorial
# saic
# Mussulmen
# curtailer
# reinterrogate
# cragged
# nonability
# superexcellent
# fingerer
# nascency
# lubbock
# pullulated
# tarantass
# jouk
# thanedom
# ectozoa
# welldoing
# ruddiest
# phacoid
# datively
# plebiscitum
# caples
# tambala
# armure
# carbamine
# yugoslavs
# obscurement
# sphenographic
# plesiosauri
# lyophilize
# sequestral
# chromoblast
# tacket
# peculate
# christianizing
# susurrus
# ephemerist
# guideboard
# catechise
# flickings
# commix
# isogeothermic
# melancholics
# arthritics
# asterisking
# dight
# lumberer
# lazzaroni
# shirky
# graveless
# rhinolophine
# plumassier
# ozonized
# hecks
# clangors
# decury
# advowee
# consentaneous
# clearstarcher
# acumination
# pulli
# demimondaine
# westered
# stigmaria
# pleurobranch
# courter
# expresser
# haemochrome
# branchiopoda
# infractor
# metrifying
# puritanizing
# intervolve
# cannular
# frisket
# fleeringly
# astronomize
# palliates
# bromidic
# pastiest
# atrocha
# obnubilate
# sipunculoid
# centrostaltic
# heterogynous
# embosom
# insphere
# undergrounder
# bladdery
# woold
# autoplasty
# heteroclite
# phagedenic
# meroblastic
# quibbler
# simperer
# septette
# dopiest
# beauish
# stackstand
# spiritualise
# ceilidhing
# caranx
# tyrannises
# analecta
# swashing
# hoosgow
# gluttonized
# gnomonics
# polyhedrical
# reecho
# biform
# tetradactylous
# monoxided
# Ustilaginaceae
# misemployment
# underquote
# concolors
# galactagogue
# serpentining
# demarchs
# skee
# uncertainness
# elaeagnus
# dermaptera
# plattens
# needlers
# stere
# disenthrone
# antistrumous
# Lungworts
# bushelled
# laudability
# trapeziums
# marbleize
# stegosauria
# taffety
# immedicable
# automatizes
# newfangledness
# niobite
# mucific
# diplostemonous
# exanimation
# enteropneusta
# laxest
# predestinarians
# pestling
# rapso
# trigynia
# irresolvableness
# bromism
# disanchor
# dialysed
# equivoque
# annunciatory
# outroared
# christianlike
# rollickingly
# hexapterous
# scalade
# ascidium
# heterophemy
# menages
# rytina
# isometropia
# rufiopin
# targeteer
# chionanthus
# longheaded
# theodolitic
# Chelifer
# countermarching
# telamones
# checkings
# splenization
# hemiholohedral
# frequentness
# ectostosis
# enthronizing
# ungathered
# montanic
# imbolden
# embanks
# palmated
# sheder
# jibbed
# beldames
# duressor
# episternum
# motorizes
# rootery
# chalcography
# periotic
# phosphorating
# enchyma
# hexine
# truanted
# bewitcher
# vaginant
# rememberings
# barbarizes
# favorer
# tilburies
# orthopinacoid
# vorticose
# flavorous
# phonetist
# Opped
# pragmatize
# rebroadcasted
# sivatherium
# tooked
# demonetize
# zygosperm
# jitterbugs
# allargando
# tautochrone
# saltmouth
# canulate
# unhand
# tubbiest
# bromeliaceous
# symphyseotomy
# galvanography
# abscissae
# reclusely
# lapidescent
# berthage
# pullings
# becomingness
# ampliative
# provisor
# cleome
# deuterogenic
# whimperer
# blasty
# privateness
# supravaginal
# depeople
# corianders
# partitively
# abderite
# cursitor
# suburbias
# architeuthis
# apprizing
# acrospore
# replevy
# recrudesce
# hundreder
# overrefine
# submentum
# unnested
# horripilated
# holaspidean
# spreadings
# urochordal
# guacamoled
# neurocoele
# scufflings
# biradial
# prefectorial
# aldermancy
# azymous
# slakes
# inhabitativeness
# dornock
# almsdeed
# septempartite
# glaucosis
# dubitation
# unnilquadium
# frockless
# oophorosalpingectomy
# smirching
# unlace
# judaization
# jollifies
# rubellite
# primigravida
# bogwood
# feuillants
# sneezewort
# confervae
# elevatory
# spherulite
# pavise
# gambogic
# vielles
# angulosity
# hennery
# concordantly
# diandrous
# intercartilaginous
# synsepalous
# galops
# Archaeornithes
# oppilation
# neurolysin
# perithelial
# deliverly
# sheephook
# promuscis
# ixc
# submaxilla
# sacci
# rinsings
# variegates
# footpace
# botanizer
# preappoint
# strappings
# panduriform
# peregrinated
# indigested
# terebinthinate
# beggarhood
# cuckoldly
# biventral
# towery
# snootier
# schistaceous
# Anglice
# honorableness
# magniloquently
# kyanol
# burglarious
# endemiology
# kapelle
# crawfords
# plumery
# monosyllabically
# ottawas
# yeet
# enures
# onomatologist
# outwind
# brutely
# porites
# stockjobbing
# laystall
# musketoon
# yeatsian
# bruisings
# pappas
# trigastric
# poppied
# locofoco
# homogangliate
# interminableness
# brushite
# coridine
# smearings
# etiolation
# elegit
# vanquishers
# ambiparous
# dillys
# frostwork
# corticotrophin
# cordwain
# sumpitan
# cuirassed
# greave
# suine
# panellings
# thallous
# roscoelite
# refashionment
# declutching
# whimsicalness
# abaciscus
# kenneled
# billsticker
# beshow
# tenuirostres
# quinogen
# durableness
# scarabee
# alcazar
# hypercriticise
# antispastic
# laurin
# gaggings
# distillable
# siss
# sanctuarize
# acerbating
# entreatingly
# disbuds
# oscitate
# stallage
# philosophaster
# maturers
# contractibility
# yodle
# ricinine
# canescent
# laxation
# turfy
# rheochord
# photology
# tomfool
# scrags
# substantivize
# orthite
# gammoned
# Brring
# polygeny
# talcked
# myrtaceous
# platinotype
# ancientry
# fontange
# strumae
# cybernation
# princesslike
# chequering
# phanerogam
# subcoracoid
# corrovaline
# periphrase
# pharmaceutist
# semibarbarism
# symposiac
# hydrosulphuric
# zemindary
# defilading
# reunifies
# presagement
# ozonizer
# wonderered
# clerid
# samaroid
# dismalness
# unfeather
# dewfall
# wakenings
# polychromate
# sermonizes
# interarticular
# ungula
# compurgation
# meatman
# pokings
# harmost
# phanerogamous
# brog
# barnabites
# phenix
# abash
# hebdomadally
# agalactous
# opposability
# seniti
# cantillate
# meteyard
# enfetter
# proportionated
# spasmodical
# serranoid
# tearings
# intromittent
# pharmaceutist
# transpicuous
# lionism
# cockneyfy
# cateran
# toddelling
# doodlesack
# archiater
# Cestoidea
# courbaril
# setulose
# orthopterous
# splasher
# carrageen
# carbimide
# palatopterygoid
# brachiate
# lamellicornia
# nosings
# glottalling
# putrefiable
# petalody
# procoelia
# predestinating
# coalfaces
# gallin
# sniveller
# mauger
# velleity
# mesethmoid
# microscoping
# deskman
# trophotropic
# mader
# attractable
# krakens
# inerrableness
# thallogen
# kitchenmaid
# apotheosising
# Aspidobranchia
# salmonberries
# oneiromancy
# endosternite
# inexpugnably
# photostatting
# handsels
# metacarpi
# cancellate
# stockinger
# liatris
# gamic
# Italianism
# protomorphic
# smearings
# unlearns
# tumpline
# sprunt
# antiperistaltic
# orbiculated
# eudiometrical
# evidencer
# rebaptize
# encephaloid
# barytic
# flintiness
# cycadaceous
# propenyl
# duffles
# sloganeer
# kitchenmaids
# disburthened
# rachides
# adenotomy
# clankless
# pierid
# Micheas
# dendroids
# catechistical
# symphyla
# brandling
# sortilege
# zooecium
# discolith
# interdigitates
# ovulary
# toat
# naturalises
# dreamful
# monomerous
# alliterates
# disacknowledged
# terebinthine
# noneffective
# unline
# commentation
# retrovert
# callot
# peridiastole
# tonsures
# tentacula
# buteonine
# disburthen
# scrog
# yokefellow
# lithotomical
# quintans
# raspberrying
# YAAB
# caudexes
# availableness
# gawps
# foreship
# overreacher
# chromoplastid
# invocating
# serictery
# outroar
# desirer
# charactery
# sibilated
# belgard
# invisibleness
# auricled
# neatens
# balker
# caughts
# ptilosis
# pistoleer
# teletexes
# morphogeny
# caseharden
# geometral
# lionly
# stringiest
# gruesomest
# hebrideans
# cromed
# pedatifid
# charactering
# flitches
# hosteller
# rackett
# headmost
# consequentialness
# nopalry
# apostrophize
# empurpling
# orcin
# rasorial
# wassailers
# stereomonoscope
# undauntable
# apopemptic
# decolonising
# disseize
# apogean
# yodle
# noncontent
# antrums
# ricksha
# stipitiform
# spreing
# unhorse
# calorification
# theodolitic
# mustarded
# hesperidene
# birle
# noils
# chicories
# defrayment
# bacteriostat
# circumgyrate
# shammer
# plumbagin
# allegrettos
# craped
# sagaciousness
# kevel
# bromated
# semigloss
# Latimeridae
# odometrical
# nowel
# wightly
# precipitability
# exuviated
# purprestures
# scullions
# commoving
# tyrosin
# welfaring
# appositions
# trichogyne
# skyjacks
# hydatiform
# allograph
# carrol
# eses
# yonker
# charlestown
# fids
# digitated
# prester
# bondable
# impone
# homoplastic
# isobathytherm
# Paphian
# shoeblack
# chaffering
# uranometry
# jubilations
# toadish
# convive
# foregathers
# phyllodium
# preferableness
# bowses
# keitloa
# infralapsarian
# aeolians
# huzza
# casehardened
# guerdonless
# isoperimetry
# sequestrates
# sustentative
# transpadane
# meatoscope
# dissimilated
# epiphonema
# nuffing
# hegari
# paraglossa
# butment
# inosculates
# revest
# undesigning
# yumas
# supras
# overfalls
# syngnathus
# yamming
# buncoed
# shaws
# androphore
# conventionalizes
# hotters
# concaved
# indivertible
# herapathite
# unlaw
# prunelle
# Hispanicize
# daker
# barbarousness
# eloin
# communalize
# tribromoethanol
# stylophones
# xylostein
# celticism
# etiolate
# Frenchify
# plowwright
# nonsynchronous
# pyritohedral
# egger
# oncometer
# pregnable
# octandrous
# inseparableness
# transpalatine
# hoppet
# lastage
# bobtails
# cric
# punchings
# pyrilamine
# storier
# magazining
# holohedral
# dreadless
# insipient
# gonozooid
# disponer
# triparted
# curstness
# defervescent
# sarcous
# bedmaker
# anticor
# afforests
# crumps
# bespatters
# availableness
# platinocyanic
# Blything
# tilleuls
# omphalode
# louseworts
# lovings
# diplococcus
# lamellibranchiata
# elytriform
# quadricapsular
# caliculate
# hamadryades
# mitriform
# unclassifiables
# warwickite
# talukdar
# jesuitism
# trickers
# flippantness
# rhizoidal
# behn
# crocketing
# itinerates
# feruling
# sixthly
# vastitude
# pullulates
# decreasings
# paraffine
# obligingness
# fieldworking
# disacknowledging
# mayoresses
# tranter
# decontrols
# cryings
# esplees
# errhine
# estrepement
# delusively
# septifragal
# resigner
# noisomeness
# chitchatted
# belzebuth
# ligroin
# maturest
# riggle
# oxygenizes
# gouted
# renownless
# desmidian
# lithocyst
# threshes
# clinometric
# coaxer
# snuffly
# cannonaded
# entrammel
# ganoidei
# hosteler
# manageresses
# organotrophic
# hotters
# homochromatic
# gonidial
# nitrifies
# slumbery
# spiniform
# unharnessing
# enwombing
# dissolubleness
# pondfish
# frostbird
# appreciatory
# domeykite
# abbing
# molybdous
# hosepiping
# dripless
# pactolian
# supramaxilla
# metempirical
# undam
# comeliest
# blindfish
# hierologic
# seemings
# uncreased
# baboonish
# palsying
# outsweeten
# centreing
# lym
# disarticulating
# eschynite
# tropine
# lollops
# stanches
# sebiferous
# impurely
# begnaw
# unplaiting
# outrides
# sycophantish
# apostrophic
# kurwa
# sermoner
# ornithopoda
# imposthumation
# pinfeather
# southernwood
# resorcin
# cruentate
# podophyllous
# waverings
# revaccinate
# sasses
# astrologic
# allowanced
# unmitre
# branlin
# plumulose
# blabbermouths
# necrolatry
# diakinesis
# quadrilateralness
# bronchia
# professionalisms
# sandiver
# Citellus
# misogamist
# buffings
# platonizing
# egoisms
# handbarrow
# surloin
# augmentable
# spatchcocks
# habiting
# fricando
# smothery
# splasher
# fluorescin
# bosomed
# dragomans
# uredo
# quinquelobed
# catelectrode
# cantharidal
# agglutinant
# cabeca
# fretter
# nigrescent
# somesthesia
# osteocomma
# areosystyle
# bechic
# lighterman
# leporid
# quadrilobate
# diffusiveness
# vulgarizer
# opinionable
# peludo
# amphoral
# conversible
# inappetency
# matrass
# elvishly
# inedited
# triternate
# kirkman
# misesteem
# bucentaur
# stroam
# prohibiter
# hotters
# accension
# ideography
# coccosphere
# whitleather
# subnotochordal
# cineritious
# ephori
# biffin
# fandangoes
# nemathecia
# hollo
# fieldpiece
# helleborein
# braiser
# slipovers
# elfins
# boreholing
# upvaluing
# iodizes
# douched
# planish
# ayen
# subliterary
# phlebogram
# typhomalarial
# keraunograph
# crateriform
# acromegalics
# mercurammonium
# clinkstone
# huzzas
# coinitial
# mantispid
# garroter
# trones
# wearinesses
# inshrine
# skilligalee
# phthalyl
# glyoxime
# scandalmongers
# aspergilliform
# spellbind
# everglade
# thoroughpin
# bonier
# xanthochroic
# bushfighting
# alburnous
# contortuplicate
# cinnamene
# polydactylism
# loof
# revealings
# pyorrhea
# mesosauria
# gelsemium
# erasion
# petextrian
# officering
# coenosarc
# malefactress
# ejectments
# varisse
# laggingly
# selvagee
# wardmote
# sewen
# succiferous
# hoodooed
# posseting
# queerish
# chaetopoda
# unsexes
# mealier
# misderive
# pesterous
# o'
# cephaloglycin
# extine
# unmixable
# telephonics
# uniquity
# jobation
# moneywort
# quidnunc
# repone
# coopts
# isopathy
# blackballs
# alkalotic
# soaproot
# ecthlipsis
# haematozoa
# russety
# necessitarianism
# kiplingesque
# mastless
# explanting
# excernent
# vegetates
# bemocking
# workmanly
# polyfoil
# tiglic
# unmarry
# uredo
# hippophagy
# honorableness
# chanticleer
# impracticableness
# siderography
# inoccupation
# revokingly
# irenical
# sparges
# lixivial
# vitriolated
# carotic
# dawnings
# longsome
# professionalizes
# delphinoidea
# reerect
# chyloderma
# rectiserial
# suprachoroidal
# dangerless
# Regularia
# teocallis
# thienone
# longulite
# rhinoscleroma
# marbly
# incrassate
# brevetting
# antitoxine
# registrarship
# carnosity
# tautophony
# variolitic
# kiowa
# acetified
# opencasting
# ostrea
# outhoused
# prevised
# mesmerizer
# Eegs
# fids
# diastasic
# billowings
# betrothment
# spliter
# beeswaxed
# pinchfist
# mesethmoid
# oxeyed
# escapologists
# seraskier
# reseats
# harmonicon
# playact
# windhover
# deictically
# eremite
# abbes
# bimetallistic
# Esculapius
# unfearing
# bezzled
# helminthologist
# lithiophilite
# vermiparous
# drabbling
# marrakesh
# gossipping
# outspanned
# elasmobranchiate
# glyconic
# cosmopolitism
# coenosarc
# pyknosis
# coetaneous
# hippoboscid
# peribranchial
# indirected
# underminings
# Tempean
# schesis
# plyboard
# doleritic
# scaldic
# codded
# thugging
# mantraps
# flirtingly
# woodier
# rinforzando
# ploughtail
# shakerism
# witenagemote
# rejective
# stannine
# impastation
# convolves
# embrown
# greegree
# halfcastes
# phosgenite
# counterblasting
# circumscriptive
# immusical
# stinkball
# hypnoanalysis
# pitless
# alegar
# cynanthropy
# naphthol
# Chufa
# silverize
# intoleration
# audile
# xyloquinone
# bumkin
# hortation
# subcoracoid
# chemism
# ghastful
# keas
# immingles
# veeing
# lixivium
# schizophyte
# hedgepig
# dogsleep
# pinealoma
# jubilated
# clapperclawing
# estaminet
# misallied
# baudekin
# antra
# confabbing
# scopula
# blite
# annulose
# eductor
# tranquillization
# fumings
# hemstitch
# wisping
# tolt
# anasarcous
# girted
# saltations
# reembarkation
# minical
# stargazed
# fluorescin
# priggishly
# chargeing
# cartwrights
# phytivorous
# chouses
# homoeomeric
# preachify
# deices
# plumbism
# eyewater
# corticate
# mythologizer
# bernicle
# spellbind
# potassamide
# dawdler
# seepings
# teasle
# papilionaceous
# prickers
# lapidific
# provisors
# pedipalpi
# sparadrap
# deliquium
# epitaphial
# calaverite
# Hederas
# aurelian
# pyrogenous
# abdicant
# sesquisalt
# zoogony
# basihyal
# proterandrous
# tiamat
# bunning
# wonderered
# mflops
# philosophistical
# terebic
# alcedo
# embracery
# overleaped
# sleepful
# quiverings
# barkings
# splanchnapophysis
# cuminil
# saclike
# velveting
# aglossal
# irreparability
# curtest
# megalohepatia
# imbark
# alcyonacea
# cacographic
# ditroite
# heterophyllous
# coigne
# companioned
# bordeller
# holohedral
# dimidiate
# anacamptics
# formularization
# flection
# heavings
# dynamograph
# apronful
# tenuity
# rockbound
# spekboom
# mostaccioli
# sneerer
# keeked
# raca
# vomiturition
# antiattrition
# chapes
# heterotopy
# fissirostral
# epipterygoid
# drudgingly
# distrustfulness
# dissentious
# brocard
# roccellin
# Sparganiaceae
# egoistically
# mixen
# supplicatingly
# monitorings
# subdivisible
# shapelessly
# stereographically
# mastax
# turnix
# tridactyle
# polytheistical
# renneting
# desilverize
# xystus
# ennobler
# bootes
# backwashed
# detestability
# calcigerous
# rancidly
# fenestrals
# eucharis
# Mariolatry
# deviator
# stabilitate
# chorographer
# styrone
# chiasmatic
# shist
# holystones
# prologued
# backcast
# conciliates
# pyrroline
# metachronism
# epidictic
# beefwood
# predorsal
# sepalous
# kaleidophone
# anteposition
# gwynn
# lawsonia
# staurolitic
# ectodermic
# epimera
# gurglings
# thermovoltaic
# eruct
# hydriodic
# softbacks
# tooked
# enclitically
# cadges
# meshugaas
# metaphysicals
# farrand
# peptization
# rosedrop
# dissert
# stellular
# binaurally
# motorizing
# refutability
# subhepatic
# sapsago
# creepingly
# tranquilness
# knops
# circularizes
# scolder
# cacodemon
# louring
# magazinist
# heteromerous
# chargings
# Hindoostani
# abstersion
# gainings
# subarcuate
# pigfish
# brabbles
# disparager
# sullage
# preoral
# spoilable
# carangoid
# houndfish
# holosteric
# handsel
# toea
# flabbies
# zocle
# halidom
# rubiaceous
# Herbivora
# stentor
# agamis
# sportsmans
# pneumatometer
# attitudinizer
# compatriotism
# farinose
# tomboyishness
# felonry
# lewisson
# ceratosaurus
# Nepaulese
# beamless
# dortour
# shadeful
# mastersingers
# sealyham
# celestite
# trouncings
# oxalethyline
# azymia
# crusta
# schizogenesis
# systyle
# amative
# redeemableness
# garbler
# rumicin
# interosculate
# cytogenesis
# avulsing
# routinizing
# algonquin
# diacoustics
# lordotic
# sneaksby
# attempter
# semipenniform
# homogony
# repletes
# olpe
# dinotherium
# multiplicator
# lobeliaceous
# overlade
# abduced
# shoshones
# sapotaceous
# megaseme
# rakel
# hybridizable
# outsails
# kairine
# amoristic
# injudiciousness
# dekaliter
# saxifragant
# Czeched
# flobert
# dipteral
# supraprotest
# herrs
# sipps
# permeative
# radicate
# labiated
# metricize
# shtik
# wooshing
# achromatized
# enunciative
# boweled
# exemplariness
# gaffsail
# elvanite
# sadda
# propodiale
# egghot
# catabolize
# regalement
# eburnean
# guelphs
# buxine
# intorsion
# dispiteous
# saccharoid
# argyrodite
# sleepyhead
# counterblasts
# arcograph
# counterbuff
# uncart
# naturalises
# impletion
# soprani
# brachycranial
# veratric
# sciarid
# easterling
# prospectless
# leviner
# improbables
# serrates
# oldwife
# carunculous
# antilogged
# overpersuade
# archangelical
# lardon
# ovaritis
# withamite
# siluroid
# valuelessness
# mexicanize
# stereotomic
# rusticates
# underpeopled
# intuitionalism
# epiplastron
# perennate
# epizeuxis
# circumnavigable
# Saturnalias
# blurriest
# coquelicot
# baldpate
# deedless
# enneagonal
# iying
# pyoxanthose
# educes
# spue
# snookering
# padder
# attracter
# roily
# vicugna
# glabellum
# chesterfields
# mantrum
# intrinsicality
# gantrisin
# animalculist
# bespangle
# interauricular
# eprouvette
# Aporosa
# mogs
# superficiary
# microbrachia
# disrelish
# sanctionative
# appulsion
# abye
# disobediently
# hematein
# populin
# spherulite
# transportingly
# imposingness
# criticaster
# phlebolite
# retrousse
# artemia
# footworn
# balbucinate
# muttons
# aventine
# tetrapody
# caird
# principen
# desulphurize
# titularity
# assibilate
# proruption
# soss
# colemanite
# outgenerals
# indirubin
# domesticities
# airbuses
# impolicy
# seachellefly
# Taraktogenos
# unreserve
# punctilios
# estacade
# scomber
# cephaloid
# allonge
# sicklemen
# ethylate
# medicable
# dynameter
# Braques
# metapophysis
# holostomatous
# bited
# gastrovascular
# rugosas
# bluecap
# pugging
# ranunculaceous
# arterializing
# pulas
# breviate
# eristalis
# edifier
# inarticulated
# bosomed
# marai
# quercitin
# teenier
# cetrarin
# martializing
# braunite
# ketosteroid
# spicewood
# predicables
# propagulum
# overcunning
# rectinerved
# transmigrator
# phyllocyanin
# rhinencephalic
# assurgency
# vakeel
# ramson
# antemetic
# disreputation
# gorcock
# pluralisms
# lithocarp
# dockhand
# parallelopiped
# pignus
# madrona
# huggered
# foregleam
# crescendi
# divaricating
# unblest
# praemorse
# Merthiolate
# spues
# metalbumin
# swinged
# envenom
# unlabored
# hepatocarcinoma
# grapplings
# inoxidize
# hebraized
# scincoid
# retabled
# versicular
# protectingly
# expressure
# peytrel
# dichotomist
# salarying
# pharmacopolist
# pantoscopic
# turfite
# delouses
# lampooner
# Holostomata
# elasmosaurus
# slank
# caparisoning
# lyophilised
# unmoor
# snortings
# exsiccant
# clientships
# pussyfooted
# checkings
# overstand
# siluroid
# unemotionality
# mummiform
# tibiale
# spinelle
# scillitin
# swops
# furiousness
# greenhead
# explodings
# roweled
# scaleboard
# terebra
# endosternite
# muriated
# imbrued
# multieffects
# lithest
# extrafoliaceous
# lythe
# rhizopodous
# uranous
# moldwarp
# anthologise
# maturated
# Leptothrix
# monosymmetric
# Plumbaginales
# cedrat
# incumbently
# spiritualise
# egophonic
# glums
# chromos
# birectangular
# pugging
# skinnys
# madreporaria
# vinculums
# microzoospore
# artaxerxes
# checkrein
# hypsometer
# cosmographies
# branchiopodous
# pistacia
# effectualness
# pseudobranch
# aneath
# ambulates
# swingle
# recapitulatory
# adenohypophysis
# eristics
# charked
# pebbledashes
# horsebean
# viridine
# essenism
# unsaddling
# branchiura
# seminarist
# harmoniousness
# splenitis
# preemptioner
# petroleuse
# entwist
# friz
# eximious
# feculae
# crapulent
# quadrivalence
# telescopical
# ponderer
# flayer
# hypostasizes
# newsdealer
# togging
# overcarry
# displode
# subtilise
# Usumbura
# blithers
# tsked
# calefactive
# subpetiolar
# unbelting
# Esquimau
# tachymeter
# interruptedly
# semicylindric
# methodicalness
# fustigate
# boul
# consonancy
# epopoeia
# filliping
# untwine
# accite
# fraena
# hydrachnid
# woolding
# piscary
# coalfish
# coparceners
# appropinquate
# fleerer
# Latinise
# Lettic
# precoracoid
# scaturient
# telephotograph
# sciagraphy
# salesgirls
# palladious
# oenanthic
# episcopalianism
# visional
# nataloin
# frounced
# caprifoliaceous
# hatcheled
# puler
# metalize
# hemitrope
# terebratulid
# mandibuliform
# cenanthy
# siphonostomata
# operameter
# circumjovial
# knag
# dinkies
# arability
# sploshing
# overfall
# muriated
# mumper
# pyrochemistry
# filigrain
# overpressuring
# beadlike
# hearselike
# proletary
# concuss
# dispreads
# splenocele
# agonistical
# pomanders
# cleped
# expiable
# redbone
# synastry
# Mycoplasmataceae
# corticoefferent
# shufflings
# coronamen
# futchel
# rudistes
# distasting
# aclinic
# fughetta
# Xylotrya
# marikina
# monochromy
# shrap
# monocotyl
# repristination
# dolichocephalous
# crepitations
# bournonite
# tzetze
# puttyroot
# enhydrous
# eloign
# pleuritical
# amitotic
# endosmometer
# devoter
# reticulating
# strophulus
# reapproach
# beeswaxes
# cocket
# moistless
# strongyloids
# reorientating
# foregoer
# reigner
# gallnut
# philosophism
# anisodactyls
# planipennate
# yardmasters
# araucarian
# surrejoinder
# neckcloths
# inflamer
# ringent
# pasteurizes
# bemocked
# smutted
# tenoning
# suberate
# skylined
# cyanosed
# unrulier
# federalizes
# capsuling
# ferreters
# greenishness
# sprod
# liquate
# lingerer
# anisomeric
# unhoped
# bonderizing
# inspersion
# ellipsograph
# ceratitis
# seedtime
# diagometer
# oos
# lymphangeitis
# orthodiagonal
# despicableness
# incapabilities
# ostiary
# shoeshining
# ceylonite
# intonate
# decimalizing
# quadrijugate
# pentamethylene
# secerned
# verticillated
# Heterotrichales
# spicated
# annunciating
# corb
# eyefuls
# Hudsoned
# endothorax
# intwine
# ascham
# loudspeakering
# indistinction
# rubbered
# caterwauled
# aquiferous
# quaverer
# autotelic
# eryngiums
# cotyledonous
# blackheart
# bulwarked
# eulytite
# dree
# arpeggiates
# epithalamic
# matrimonially
# consociations
# vermicular
# Mesozoa
# demiculverin
# backburnered
# gyroidal
# incrassated
# overscored
# adunc
# lariating
# tracheate
# epitasis
# pinnipedia
# fluxionary
# haemin
# recrement
# harpings
# hippocratism
# cachepot
# pipra
# ricker
# arctation
# albinoism
# leptostraca
# generatrixes
# rhodanate
# assignability
# hypothecs
# maplike
# scandic
# paganizes
# syncretizing
# alibility
# calabarine
# peepings
# breasthook
# alchemize
# naphthalic
# disburdening
# loweringly
# pyrena
# skyed
# destructionist
# enophile
# alloxantin
# extravasate
# interlines
# Southernism
# coalitionists
# osses
# rentered
# corallaceous
# precook
# bellyful
# yardbirds
# gallipot
# amotion
# moraceous
# xyster
# stive
# greaved
# pollenize
# robustious
# bristletails
# debonaire
# softnesses
# precognitions
# gypsoplast
# snaphance
# covariations
# tungstite
# misdeals
# inspissate
# hyomental
# aerobacter
# jeoparding
# wantoner
# Johannisberger
# marrowbones
# calker
# residentship
# quadrivial
# musaceous
# ecraseur
# ovums
# Russianize
# reexchange
# puppys
# ashler
# pluviometrical
# thenardite
# unessentials
# basanites
# deforce
# palification
# ameliorable
# zemindars
# backjoint
# nihility
# bioplast
# ophthalmometer
# configurationism
# curvity
# slowings
# messeigneurs
# boracite
# rotatoria
# snaggy
# uranolite
# abscising
# testiest
# neurapophysis
# heliotropic
# aerometry
# owse
# heisting
# ambusher
# bumbailiff
# unicornous
# aerified
# semiparasite
# twingeing
# erumpent
# sporulated
# Jacqueminot
# castigatory
# seabeach
# casals
# tightroped
# stemple
# wauling
# polypidom
# chirrs
# discourser
# housekeeps
# ruggedize
# sacramentalist
# incalculability
# catabiosis
# evolvent
# bolthead
# sinalbin
# tephrite
# extendedly
# carmagnole
# titillations
# orologist
# embossment
# verdin
# bransle
# squinched
# drolling
# anury
# bikh
# pawnor
# straitening
# dragonnade
# refunder
# firelights
# bioclimatology
# orcin
# mutule
# hybodont
# outcrying
# forelift
# mausolean
# solifidian
# drawboy
# jovialness
# immunostained
# operoseness
# virginians
# brittler
# mauritanian
# wifeless
# rubrician
# taction
# pregnantly
# myringa
# rememberings
# sozzle
# zymological
# clangors
# monotrematous
# bryonin
# cylindricality
# doat
# impostorship
# jeffersonite
# stathmograph
# pluvian
# kevel
# unyokes
# Hobbism
# emplaned
# reassociate
# tipsier
# kinkiest
# snift
# mesitylene
# tardier
# rachialgia
# formulized
# sesquibasic
# stemlet
# corollated
# superglues
# thallous
# phrenics
# epigrammatical
# sparaxis
# lispings
# mosasaurus
# nodosity
# cancelli
# contortuplicate
# sequacious
# toadhead
# dunged
# yaguarundi
# queenlike
# sovietizing
# legumen
# twinborn
# creance
# moiling
# croze
# babylonish
# pantheistical
# detribalizing
# circumclusion
# indol
# bastes
# episperm
# fenceless
# preceptories
# ditokous
# meteoroidal
# sudamina
# tenuirostral
# huers
# murillo
# heterodactylous
# glandulous
# toreutic
# dioptase
# baggings
# scythemen
# foreknowing
# tetrabasic
# holocryptic
# stickles
# osteocolla
# penholders
# hypnocyst
# scall
# arhythmic
# lithaemia
# Ichthyosauridae
# residenter
# cragged
# sanctitude
# amphictyonic
# sciolistic
# scuttered
# turanians
# sallows
# miaou
# bestar
# externalizations
# rhob
# chloralism
# chaetal
# pinchbeck
# shamoying
# antitypical
# wellhole
# amplexicaul
# antaean
# momentaneous
# berthierite
# pulvillus
# buncombe
# Vaticanist
# stenographed
# maculating
# pauling
# adversaria
# flamy
# taillike
# ensilaged
# stodgily
# exsiccate
# cladode
# coronule
# gratiolin
# obeseness
# wonned
# inoxidizable
# literatim
# schematise
# brackened
# meteorograph
# lastage
# subnasal
# fraxinus
# preadamic
# incremate
# lactucarium
# dungs
# materialness
# proostracum
# sparling
# scaliest
# bombycinous
# endospermic
# allegorise
# spectrological
# tetramethylene
# cardiometry
# torquated
# spessartite
# troutling
# huronian
# caverning
# gangliated
# aftergrowth
# sylphlike
# doloroso
# anchorable
# gemaric
# swink
# savagism
# jalousied
# exultations
# invectively
# mephistophelian
# spinate
# anticatarrhal
# cucullated
# titrator
# carvene
# septfoil
# tubfuls
# carpetings
# laminiplantar
# snipings
# deadlatch
# effloresce
# becharm
# macartney
# vanting
# mump
# zimb
# villoma
# otacoustic
# insipience
# univalvular
# masticator
# porer
# Desmodontidae
# goar
# chylifactive
# microcrith
# coleorhiza
# mistigris
# roysterer
# bipedals
# sasin
# courap
# decrepitating
# pneumonoconiosis
# Hibernicism
# myelic
# predicables
# syllabized
# androides
# federalizes
# dibbles
# spermatize
# seminate
# introspectionist
# monopathy
# damnified
# unblind
# youngger
# sulphonic
# devastavit
# Sarcoptes
# sprent
# backsaw
# uropod
# choriambus
# yielder
# hemagglutinated
# eozoonal
# resolutioner
# stereometry
# headfuls
# clangoring
# hypnotization
# parget
# invisibilities
# adamic
# sidebone
# pennings
# weigelia
# cyanogenetic
# balneology
# hydrostat
# ringsail
# ocularly
# calorifere
# lackeyed
# notchboard
# virtualities
# illuminism
# anagramming
# compsognathus
# incognizant
# receptacular
# goin'
# machicoulis
# plumula
# morphotic
# spellbind
# esthesiometer
# downwarping
# vaunter
# antizymotic
# isatis
# eternizes
# hurriedness
# theandric
# wagerer
# uninquisitive
# septemvir
# bushwhacks
# cryocautery
# confoundedness
# repullulation
# titubate
# brazening
# antisplenetic
# replum
# canaanitish
# propodite
# theorizings
# adactylia
# pences
# isonicotinic
# coversed
# discording
# lotioned
# karyoplasma
# mesocephalic
# subjugator
# shent
# narcotine
# besetter
# chewiest
# arachnidan
# xanthodontous
# musciform
# NbW
# agrypnia
# misapprehensively
# torreon
# intersectant
# djinnee
# eunuchism
# upburst
# abutter
# lysogenize
# decameter
# shoeshining
# inned
# kiloliter
# anorthopia
# navelwort
# inexecutable
# hospitalism
# smatter
# postponer
# oxymethylene
# wotteth
# fetor
# consociation
# blenching
# dispeople
# hemihedral
# karyostenosis
# actinology
# disboscation
# stinkard
# digitated
# Jacqueminot
# adenology
# chawed
# agenesia
# underplot
# waggoning
# appendiculate
# holsteins
# drawbore
# palmerworm
# dizygous
# breasthook
# inexpiableness
# hunterian
# impest
# undecidables
# rhymeless
# diageotropic
# dakoit
# empyreuma
# childishnesses
# traject
# almains
# truckles
# multiformity
# inweaves
# comprint
# billhooks
# caseate
# rushings
# smelless
# hemostasia
# dolour
# digitiform
# guitguit
# quicksilvered
# maniform
# hydrorhiza
# goudron
# engrail
# steerless
# ascolichen
# pretermits
# rhapsodised
# impugnation
# steatopyga
# feminineness
# inexpertness
# goldbrick
# abaciscus
# sarcophile
# polybromide
# unveracity
# fantast
# prelatical
# cerusite
# spongiopilin
# vitrifying
# icemen
# bathymetrical
# flaxy
# podgers
# flusters
# councillorship
# tabularization
# immuring
# resemblingly
# tarsectomy
# tachygraphy
# lutidine
# cankery
# evaporometer
# ballyragged
# occludent
# scruffed
# impetratory
# holinesses
# glochid
# rhizocephala
# photozincography
# tetraspore
# lambskins
# peroxidize
# connaturality
# baurs
# backshish
# isidorian
# calcifugous
# resistibility
# Cses
# alkalinities
# capric
# meatotome
# bargainor
# elbowchair
# cochleate
# taurocholate
# apothegmatical
# ladings
# moujik
# outstep
# acrania
# spoilation
# talcous
# actinometric
# pleaseing
# sextodecimo
# assorts
# echinococci
# torturings
# vrooms
# nitter
# infusionism
# scammoniate
# trispermous
# bigly
# propodiale
# bountifulness
# hematocyturia
# urticated
# indevotion
# interfusion
# knacky
# mollities
# talkin'
# arciform
# foundationless
# cimices
# avaunt
# diversionist
# dobras
# philanders
# leggier
# unitize
# neurotomy
# Osteostraci
# pineries
# regenerateness
# algaroba
# traject
# miascite
# covin
# biassing
# smackings
# chinse
# mozartians
# shoshones
# corbina
# hazelly
# anisostemonous
# slantways
# saintess
# sprawler
# oxhead
# betrimmed
# admeasure
# glibbest
# requisiteness
# iatrochemical
# cruor
# uberous
# scaroid
# runed
# ascosporous
# gauntness
# bubbliest
# darns
# cretonne
# jumpier
# pyramidic
# upvalued
# bleacheries
# perfecter
# benzal
# statued
# animalise
# attorns
# fenceless
# uprises
# cloggies
# endostosis
# mastics
# hematosin
# pintados
# nervimotor
# aubin
# onocerin
# wentletrap
# pestalozzian
# scamble
# costeaning
# fishbones
# unclothe
# candlewood
# rimeless
# clumber
# multiplicable
# increate
# paintless
# pinnas
# octennial
# trimetric
# intermundane
# wettings
# oilcan
# twirp
# dunkings
# terminational
# ideographically
# aeolipyle
# cymidine
# trehala
# hysteroepilepsy
# simoon
# postmortal
# emictory
# candelabrums
# refaces
# driblet
# benthamism
# sipunculoid
# domiciliating
# neuroepithelioma
# concernedly
# chlorous
# spadefuls
# monisher
# cheeps
# minacity
# carbazotate
# tunned
# monardas
# iridian
# reechoing
# traject
# kingdomed
# assart
# shrinkwrapping
# postglenoid
# discommon
# phytological
# specializer
# marcionite
# glazy
# anamniotic
# aliturgical
# glaucine
# bedfast
# rubian
# beguiler
# surcingled
# scarcement
# chondrigen
# promisees
# approbates
# celotomy
# usnea
# dowlas
# princeless
# rimer
# unlooses
# brainsick
# roisterer
# sagenitic
# congression
# anemograph
# summertree
# besots
# roughhouses
# perfectively
# laurin
# byroads
# karyostenosis
# nullipara
# foreright
# endotheca
# epizoan
# cooperages
# pasteurising
# dispark
# helenin
# tubulous
# markoff
# tweel
# acanthine
# spraddled
# mestee
# sublobular
# doughtiness
# polariscopy
# itala
# proseman
# denary
# planoconvex
# rethreaded
# velarium
# alizarine
# tinmen
# urson
# momently
# adustion
# gaucherie
# jugoslav
# malvaceous
# unthread
# cicisbeism
# hermitical
# venomed
# dichroscopic
# discussive
# lunary
# fanega
# saltmouth
# fructifies
# zonule
# flightily
# baunscheidtism
# holometaboly
# helving
# disliken
# binervate
# interhyal
# raggie
# buckers
# euplexoptera
# counterguard
# conferrer
# quadrasonic
# scurfiness
# flambeaus
# selion
# platitudinarian
# glossography
# Ziam
# individuates
# gastight
# onagri
# posturer
# upstands
# escalader
# sensoria
# yieldable
# impetration
# feretory
# spiritualty
# quartter
# latices
# disfavouring
# diseasing
# hexabasic
# trimorphism
# biplicate
# gibing
# superplant
# excruciate
# turnix
# hypostasizing
# calcines
# gastrocolic
# perineums
# athelings
# oopak
# reclaimant
# synanthrose
# transhape
# chined
# ceraceous
# psalmodic
# nonassertive
# gallinacean
# sheepshearing
# octodecimo
# deliberator
# bouri
# pseudovary
# eructate
# roselite
# venatic
# excommunicant
# sibbens
# amphid
# orbitosphenoid
# overcasts
# misbegot
# caustical
# meride
# ombudsmans
# spagyrist
# labefaction
# enterolith
# yaffle
# relapser
# phosphureted
# louting
# reannex
# dissever
# acuate
# contrivings
# prototheria
# amputator
# goodyear
# posnet
# emolliate
# hessite
# Pupipara
# halieutics
# gasoscope
# tottery
# nigglers
# blattered
# boshes
# quartter
# fittedness
# physianthropy
# idioblast
# reseeds
# niveous
# mandibulated
# exercycle
# hypersensitized
# staphyloma
# ricked
# mascagnite
# superannuate
# cabinetwork
# exocoetus
# shealing
# Rhincodontidae
# chylaceous
# alburnum
# orthogonalises
# antiochian
# monorhyme
# gratulate
# sirkeer
# mischoose
# musset
# delvings
# polymathy
# marling
# actinometric
# deglamorising
# chichipe
# reclination
# antiperiodic
# greathearted
# desublimated
# circularise
# wonned
# disserviceable
# trowers
# bounderish
# entrancement
# agonistical
# returnings
# whatsoe'er
# balkiness
# waverings
# cicatricle
# glottologist
# apophthegmatic
# cascalho
# emplanes
# appellatively
# overslaugh
# ronne
# oleographs
# granitification
# hypotarsus
# velveting
# runlets
# homalographic
# garmented
# remobilizing
# anthracic
# trapanner
# countermark
# abider
# aristology
# fraughted
# inconvincibly
# camlet
# deracialized
# neuraxis
# acidulate
# bechanced
# hickwall
# hellman
# ordainable
# doucet
# excruciation
# ectozoan
# tuckering
# frizzles
# carbonade
# marauds
# fellness
# arbitrative
# rantipole
# illustriously
# bindingness
# singularizing
# rumples
# vizarded
# livingly
# distaffs
# oleiferous
# fairily
# straths
# rhetoricals
# toreadors
# parricidal
# unchristianly
# histogenetic
# obbligatos
# prates
# abscised
# corves
# hypersensitised
# southron
# perishableness
# pahs
# grampuses
# thermalling
# polyandrist
# xylographic
# fallopians
# atonable
# kairoline
# nectarous
# illegalise
# kinglike
# pashes
# categoricalness
# oreide
# sordine
# scrams
# hypothecator
# unrip
# apostrophizes
# triding
# impennate
# boileds
# republicanize
# subereous
# planished
# jointress
# decuries
# cursively
# garrottes
# hosepiping
# entrancement
# susurration
# territoried
# unbraces
# fehling
# passeres
# phonated
# endosmotic
# peperino
# exoterical
# skedaddles
# urechitin
# paralbumin
# thewy
# overfond
# galvanometry
# vivandiere
# neologize
# reboil
# systemizer
# larviform
# megametre
# conventicling
# imparlance
# tupik
# signalizes
# ecureuils
# urinous
# quicksilvering
# gymnoblastic
# oedematous
# methodizer
# playschools
# galveston
# interjectionalize
# yerk
# falconing
# alutation
# rounceval
# Gephyrea
# scrophulariaceous
# georgics
# kilting
# glams
# leporine
# promisors
# electrolyzable
# raddle
# coparcenaries
# puppys
# calcuttan
# halloing
# pierides
# enflowered
# subcarboniferous
# blae
# sterlets
# anaglyphical
# interamnian
# hyoscyamus
# toadstone
# microtasimeter
# anility
# vaselines
# joinering
# trothplight
# hypostatical
# surfacings
# imputrescible
# precisive
# oxanilide
# easterling
# fanaticizing
# disseat
# sharpenings
# valeric
# lache
# hyracoid
# outfrown
# regentship
# superannuate
# reflectives
# unsociably
# lades
# Voltairism
# suspensorium
# keratogenous
# oilery
# omphalode
# pursuable
# intercavernous
# disbench
# shamas
# pedate
# wahabee
# lithophagous
# footmark
# cramponed
# untack
# brazilin
# congeed
# moonsail
# vinasse
# princeliness
# depolarizers
# rhyparography
# grangerism
# impanelment
# cornicle
# papalize
# metamer
# dictamnus
# extrabranchial
# planimetrical
# middler
# reliableness
# nowel
# journeywork
# educt
# bustiest
# conarium
# thalline
# bluestockingism
# oriency
# phantasied
# rhabdoms
# columnarity
# corf
# organizable
# snufflings
# inadherent
# demed
# servicings
# wourali
# procatarctic
# roarers
# harbingered
# unvulcanized
# aquatinting
# levants
# buxomer
# goutily
# theologise
# inviolableness
# parelectronomic
# mummifies
# parostosis
# rotc
# savingness
# surveyorships
# protectrix
# abdicant
# amorist
# pyrargyrite
# abnegator
# speirs
# gaud
# subesophageal
# verderer
# nosiest
# disaccords
# witherings
# brassage
# okenite
# gabardines
# priestlike
# resorcin
# octahedrite
# gelatinizing
# orthoscopic
# excruciated
# Ascococcus
# carbonometer
# cursedly
# pinacone
# ambrosially
# stringendo
# can't
# hypophyllous
# antiochian
# dyspneal
# symptomatical
# posterns
# decreer
# christianising
# refrigeratory
# brachiata
# sarcina
# vilenesses
# desireless
# interlacement
# chrisom
# presystolic
# noddings
# hemipode
# kusimanse
# euphory
# cornopean
# veals
# linkwork
# acaleph
# runged
# chemisorb
# barcon
# cleavelandite
# copaiba
# freewheeler
# pretorium
# vugg
# pococurante
# chassepot
# monodies
# grumose
# pulmonated
# shintoistic
# ultramontanes
# tracheoscopy
# utilizer
# pavise
# Gordiacea
# ploce
# trustily
# unbark
# Stiched
# larum
# sylphid
# illegitimation
# wafered
# dissertational
# reachings
# foreordain
# hexahemeron
# Implacentalia
# kitcat
# manumotive
# hydramine
# abreacts
# imprested
# sconced
# chargeing
# harmost
# kinased
# Teutonicism
# thonging
# neathouse
# teleutospore
# fluosilicate
# unemotionality
# yaups
# mohicans
# impulsions
# eventuation
# hirudine
# circumscissile
# deistically
# stylopodia
# lodgments
# cathecting
# biologistic
# muniment
# disencumbering
# oxidated
# romaunt
# nudnick
# psammites
# divorcer
# countermure
# teneral
# dihexagonal
# anthroposcopy
# communize
# cholagogue
# frolicky
# ensky
# hagseed
# discerner
# hydrargyrate
# impleading
# merbromine
# barebacked
# fungate
# pretendingly
# hemitropous
# paperclipped
# gavot
# estacade
# labionasal
# ilias
# bunning
# xylic
# modernisings
# manucode
# dissolvent
# zamouse
# barelegged
# outclimb
# tachogram
# hortation
# nugae
# checkings
# habendum
# faithlessly
# indagative
# flucan
# wiredraw
# mastodontic
# dichlamydeous
# avoset
# ectomere
# photics
# kinghood
# xanthosis
# turnus
# deambulation
# peripterous
# pentagynous
# gonfanon
# polyporous
# historicisms
# embrangles
# longicorn
# celature
# hodiernal
# lordlike
# assart
# telephotography
# perried
# turfy
# stallings
# jointings
# hornito
# ethylidene
# gruffs
# stere
# feilding
# schistosity
# elasipoda
# irresoluteness
# pantisocratic
# drudgeries
# sideral
# weisses
# impearling
# literalised
# ethenyl
# microspreading
# phutted
# navelwort
# misvalue
# adeptest
# dogmatizer
# discountenancing
# shrewmice
# pentone
# rubescence
# exhilarant
# banefully
# incommodiousness
# astringing
# snift
# galvanoscopic
# anchoresses
# succubous
# feaze
# vincas
# subthalamus
# cryohydrate
# herpetologic
# vulviform
# apriority
# cerebrifugal
# krumhorn
# embossment
# rachiodont
# cockspur
# lapidescent
# protomorphic
# spoonily
# murrhine
# verbalises
# pursual
# winceyette
# cacajao
# harmoniousness
# purfle
# mesovarium
# scholiums
# flatlets
# affiancing
# protosulphide
# architectonical
# diffusor
# pruinate
# shmucks
# cabalistical
# palaetiology
# elaterometer
# homotypical
# pavans
# comanches
# formings
# mobcap
# tackless
# interlard
# subarachnoidal
# syllidian
# stalder
# gardenless
# upas
# astrolater
# meconin
# emulousness
# tangibleness
# beldame
# billowings
# vaginula
# lipogrammatist
# fub
# frutex
# spearer
# rodomontade
# photologist
# Burdoned
# cleistogamic
# adrenocorticotropin
# aphorismic
# hypaspist
# curviform
# foregoer
# bootlicked
# hemadynamics
# coyed
# pseudomorphous
# fette
# outmanoeuvreing
# Casuariiformes
# checkage
# interfollicular
# gnarl
# depressomotor
# anacardium
# avengement
# dopings
# phalansterian
# blottesque
# rusine
# commensurating
# Londonize
# decerebrates
# colorcasted
# propitiable
# valerianaceous
# questionary
# bumpkinly
# dowdier
# terminist
# smatterer
# sarcocarp
# manuduction
# diocesans
# prickings
# whimperings
# chapelet
# tentaculocyst
# yucateco
# impetrative
# mizen
# overcrow
# oxters
# Spermophyta
# degass
# prolicide
# scatophagy
# osmious
# nippier
# muncie
# cemental
# uded
# autopsical
# syllogistical
# cispadane
# tumultuary
# caligo
# spermospore
# valletta
# umbilication
# thirled
# paludamentum
# incongealable
# gummatous
# zincous
# patternings
# hematophilia
# canalled
# viselike
# Ephedraceae
# unevennesses
# subnormals
# Penances
# tractile
# micromere
# chronogrammatic
# rhythming
# countercheck
# gustard
# coccal
# synantherous
# corianders
# parapleura
# manganous
# cassations
# leese
# grayback
# ynambu
# morns
# stoutish
# dagging
# seedcase
# paguma
# spadices
# axstone
# sericultural
# sennight
# eponymist
# incisura
# fibrinoplastic
# hydrobarometer
# hindbrains
# lockkeepers
# caterwauls
# confineless
# sourball
# underbuilding
# affranchised
# beasthood
# osmate
# babyhoods
# spininess
# copyreading
# introjects
# Haplosporidia
# somewhither
# sulphinide
# buskined
# algate
# starveing
# semoule
# depictured
# dessertspoonful
# aplacophora
# orthotone
# illume
# creepingly
# abarticulation
# sarcocarp
# peckings
# phyllodium
# sacrovertebral
# endways
# gastrodisc
# eosinopenia
# hyperlipaemia
# uranian
# sludged
# putamina
# mitchella
# phospham
# phthalide
# retruding
# rickstand
# avale
# Monozoa
# enantiopathic
# acalycine
# balsamine
# tesseral
# injuriousness
# mucedin
# spewy
# disannex
# sublimatory
# precipitantly
# sorn
# deforests
# wardsman
# disarmer
# nebcin
# impedimental
# womanize
# gelatigenous
# stilting
# weares
# eschscholtzia
# sulfuretted
# gonochorism
# bandiest
# voidance
# sipunculoidea
# segs
# sidesplitter
# telangiectasis
# lukks
# murmurer
# sociobiologic
# procyon
# spilikins
# wyclif
# houghing
# leghorns
# aptest
# odling
# coquimbite
# vermivorous
# climatizing
# poundages
# basihyoid
# correctioner
# narcotism
# pauperise
# curarine
# glebeless
# strepsiptera
# imposthume
# eudemonistic
# dambose
# antiserums
# ohmage
# irreducibilities
# sheather
# evacuative
# sagenite
# runed
# corrugate
# adenium
# scepterless
# marceau
# contignation
# underwork
# cervelat
# underprices
# spongoblast
# recife
# ossific
# elastoplasted
# rugosas
# averager
# undercliff
# hollo
# homogamous
# cruorin
# coccosteus
# snuffy
# Picentary
# interfuse
# Listerism
# glycocoll
# rogueship
# clapperclaw
# chargeing
# Coleridgian
# slaggy
# glenoids
# thermometrical
# Exocoetidae
# unriddle
# chlorpicrin
# carnelians
# mechanography
# earlocks
# placentary
# maxilliped
# alnager
# elaphine
# shirtsleeved
# ungues
# manciples
# indissolvable
# zetetics
# trephines
# servian
# panful
# religionary
# scandalises
# suspectless
# valonia
# deafer
# dispirits
# discommend
# automath
# gyve
# Romeward
# pentandrous
# eremacausis
# sagger
# endosteal
# xylite
# benempt
# profferer
# myotomes
# indemonstrability
# readvance
# cestoid
# sclerogen
# shufflings
# thingummies
# foolfish
# pseudomorphism
# bowse
# encage
# refashionment
# imporosity
# cockleshell
# bescribble
# digressional
# parelectronomy
# clumper
# sternohyoid
# antasthmatic
# intercolumnar
# foreside
# consumptiveness
# botulinal
# diacaustic
# postliminy
# numerates
# detrition
# cotquean
# bolled
# drowsier
# toggery
# dunder
# sneck
# gnathostomata
# hipline
# outness
# uranin
# pepperidge
# habilitates
# costellate
# chatterings
# ametabolous
# vermifugal
# dahlin
# sublimatory
# daguerreotyped
# zunyite
# conciliabule
# infolded
# puritanic
# moonraker
# conductresses
# shikaree
# Hoprah
# navelwort
# kibed
# spreadings
# spurgall
# froings
# langaha
# acosmist
# quadriphonic
# deflagrable
# thermoforms
# Syriacism
# hackly
# caliculate
# pomatum
# malties
# locellate
# pinacotheca
# nagyagite
# mesaconate
# setaria
# bootikin
# paragraphic
# tabbinet
# plasmogen
# yucateco
# dermic
# peakish
# neurility
# scolopendrium
# aristarch
# drabbler
# fovilla
# harmel
# readjuster
# smoothens
# myofibrilla
# trapanned
# ...
# logography
# assessorship
# jackmen
# episcopated
# cathartin
# luted
# emptinesses
# inspectorial
# depauperated
# chigre
# cloop
# paronymous
# deblai
# enterokinase
# haemophilic
# crofted
# homologic
# cliquishly
# gley
# wried
# bloring
# twangle
# serges
# hydrokinetics
# punchinello
# bindheimite
# bettings
# postsphenoid
# discolith
# pirl
# epithetic
# boce
# teleorganic
# garreted
# sporing
# finicking
# psychal
# eyebrights
# Erysiphales
# claspered
# valvula
# guerite
# antiplastic
# potmen
# superstrain
# notandum
# osculant
# noncompletion
# inequilateral
# sphacelus
# hesp
# deadener
# grubbied
# gretzky
# northwester
# necessitarianism
# procoelous
# hybridist
# brillancy
# incle
# oncotomy
# miniaturizes
# internuncial
# birred
# convolvulaceous
# imbursement
# underbranch
# virulency
# interpellates
# palmiped
# trebleness
# overexquisite
# solidism
# unlay
# croupous
# airbraked
# theologize
# metallochrome
# subsulphate
# colossian
# capetians
# hornfish
# thirling
# tumular
# alguazil
# acronychal
# polypragmatic
# brazilin
# ophidian
# solidifiable
# needlebook
# tearings
# metheglin
# arthrodia
# sturt
# Milontin
# Pilchers
# passeres
# trothplighted
# cherup
# fluxionary
# Xiphodon
# hoosiers
# loaming
# amphisbaenoid
# bechance
# tarente
# goosefleshed
# palatalizing
# bryonin
# unnested
# protectoral
# nosings
# biradiate
# incurvity
# monomerous
# dartle
# disembogue
# stasimon
# smatter
# subpubic
# Christly
# muscatels
# wawls
# poleax
# manifestable
# thalassian
# eyra
# multiseptate
# thickhead
# selenious
# charnels
# Allantoidea
# resaw
# checkings
# Herrnhuter
# pragmaticalness
# roaching
# syncopates
# exceeder
# enveigle
# animadverter
# orismological
# embroiler
# branchiate
# testudinal
# atopognosis
# waterskins
# monomorphous
# shiftiest
# scyphistomata
# mizzled
# poshed
# tridecane
# tanier
# sericeous
# paroccipital
# pentaptych
# thecodontia
# cohobating
# fids
# peasen
# cyphering
# condoler
# metallograph
# mercerize
# roughcaster
# gustative
# sputterings
# imparity
# dermoptera
# hsing
# fractiously
# featherings
# sighings
# animalcular
# unsheared
# stagnantly
# synaptase
# despread
# organule
# caverned
# heteroclitical
# tiltyard
# Riting
# choky
# sixscore
# maziness
# cismontane
# exoterical
# pastorage
# solpugid
# alleluiah
# controvertist
# syndactylous
# fastuous
# trebleness
# fineable
# pottled
# oenomel
# supersensitized
# blowzed
# coralliform
# hepar
# muscatels
# slackest
# coleopterist
# limitary
# trimetrical
# Streptomycetaceae
# expectative
# misshape
# intersternal
# dreader
# otaries
# buffin
# euhemerize
# bicornate
# orthostichies
# overfall
# Pediculidae
# digitalise
# benzal
# extrusives
# datolite
# starchedness
# tabernacled
# flaxed
# clupeoid
# stethoscopist
# Menyanthes
# phyllomorphosis
# timbermen
# cinnamone
# ecumenic
# Shemite
# unpedigreed
# tartareous
# subbrachial
# thiouracil
# hypercriticise
# sucrate
# repugned
# parvoline
# fluffies
# scourings
# suffumigating
# hypoblastic
# gelechiid
# silurus
# primogenitor
# ingrafts
# hypocraterimorphous
# drawplate
# Shavians
# knelled
# overturner
# ribboning
# dietetist
# glummer
# sprechstimme
# depicturing
# interlobar
# bottone
# sulfamethazine
# fusillading
# physostomous
# undersleeve
# deafer
# tubulure
# vocalizer
# vesturing
# slakes
# phaeospore
# staddles
# sphygmometer
# distichously
# anfractuous
# chesses
# docimology
# guanidines
# endogeny
# toolhouse
# saxifraga
# antisplenetic
# phlogotic
# regerminate
# ascarid
# heliochromy
# subvene
# terneplate
# rubberizing
# aurantiaceous
# mainprise
# creosol
# emblaze
# blackcock
# joinering
# OOMF
# idgaf
# vixenly
# propitiates
# siphonata
# cerite
# subluxate
# travelable
# assot
# waterwort
# peccable
# pedestaled
# monosulphide
# bescreen
# vibrative
# gainable
# jackstraw
# outness
# ichthyophagous
# involucrums
# statedly
# jackstone
# erythrin
# descale
# radiatiform
# ajutage
# tuitionary
# xyzpdq
# dualin
# hoariness
# anchylotic
# pteropoda
# irrupt
# maternalistic
# proscenia
# condescendence
# bailiffship
# flowerage
# siennas
# clabbering
# empaistic
# cyclostome
# autotomic
# spermatospore
# mistier
# cosen
# saccharase
# convincer
# rhachides
# outthrow
# punctated
# avener
# besmearing
# kutuzov
# detangles
# idiocratical
# drawbench
# vulgarizations
# nineholes
# dialyzation
# photosculpture
# grubbied
# keenings
# penultima
# uprisen
# septicidal
# bistouries
# basan
# chargeably
# salicylal
# unsexual
# palmipedes
# effervescency
# coromandel
# lapidification
# hypermetropy
# sconcing
# colligation
# utia
# atmological
# genethliac
# decene
# paramorphous
# spitbox
# petronel
# paramylum
# rabbinist
# outstand
# guelfic
# chirper
# anthropopathism
# tallyho
# antelucan
# bicostate
# radicated
# amidin
# melaphyre
# amphistylic
# peches
# salvability
# homospory
# imbalm
# baculine
# ranine
# loculous
# yerd
# surtaxed
# eventration
# mystificator
# biyearly
# cockaded
# ratability
# darbyite
# unchains
# trichinize
# gradine
# carnifying
# pimelite
# digonous
# seminoles
# canaster
# balloonfish
# titivates
# turmoiling
# urceolus
# hodman
# Ophioglossales
# nief
# babist
# attle
# myodynamometer
# wimbling
# helenium
# heliotropism
# bashaw
# tankered
# viring
# abider
# blitherings
# dreadlessness
# ladify
# crossbarred
# muddily
# blackleading
# impartible
# corchorus
# branlin
# ebrieties
# blackener
# antas
# remissive
# crenellating
# shieldtail
# chuting
# philandered
# untime
# procacious
# intersternal
# frostiest
# dioptrical
# souchong
# hornito
# superfrontal
# pillau
# spillers
# zingiberaceous
# abbreviatory
# beccafico
# buffings
# amphictyons
# vyvanse
# thines
# deoxygenating
# straitens
# henpeck
# pseudosounds
# tailboard
# magnifical
# tooked
# pachouli
# shiest
# concinnity
# stromas
# isodimorphism
# schoolmistresses
# hunkerism
# metrified
# mordanting
# trephines
# eskar
# alkahest
# alcoholise
# o_O
# fendered
# fabella
# cyclostylar
# housecraft
# ebulliency
# responseless
# bushelling
# vermonter
# abashedly
# lemnian
# morbifical
# cuckoldly
# partibility
# naphthazarin
# chrismal
# superincumbency
# chasings
# isochasm
# neruda
# aerifies
# disseizee
# amphitheatrical
# rakishness
# multidentate
# beltings
# gyve
# generable
# weekended
# antichlor
# reaumur
# reaumur
# arbored
# naffs
# petiolated
# pitheads
# ashler
# beeding
# goitred
# theorematical
# buffalofish
# alcanna
# Kampucheans
# dorsiferous
# silicify
# wantingly
# crashings
# extrasystole
# Irians
# phantasmagorial
# cerography
# echoer
# ichthyomorphic
# metallochrome
# cliquism
# cowhage
# neoterize
# goujon
# feelered
# achenial
# sideling
# xerophilous
# dumbstricken
# schematizes
# padnag
# lactonic
# niveous
# neuroskeleton
# expostulatory
# pitmans
# squinnying
# trifids
# chuses
# podosperm
# moroxite
# runningly
# uroerythrin
# kingcups
# favouritisms
# orthognathous
# chaunt
# methide
# mesohepar
# deuchars
# amort
# liquation
# upheaped
# swordlike
# slatt
# dibranchiate
# mosstroopers
# diaheliotropism
# algometric
# atmidometer
# sclerodermite
# classific
# saxifragaceous
# foregroundings
# analepsis
# aneled
# chastisable
# sheening
# rhabdite
# sincerities
# temperateness
# fraudulency
# blinkard
# genette
# venturesomeness
# erective
# predestinator
# lithontriptic
# annulose
# ninthly
# recure
# cordonnet
# gally
# spiry
# strokeing
# predicables
# remembrancers
# isotrimorphous
# nubbles
# earlock
# lumbrical
# coppens
# vinasse
# gleamy
# possest
# coquet
# repacker
# darbies
# camail
# bookbindery
# slitherings
# fermentability
# wimble
# bustler
# commandress
# examinant
# nipplewort
# currycomb
# metronymics
# bibliolatrist
# decimalize
# furbishes
# mercerise
# soothsay
# soprani
# typhlosole
# checkrow
# lapboard
# bdellomorpha
# equipollency
# lionet
# sleepered
# worsteds
# scleroma
# frostless
# Eunomian
# indigotin
# entoprocta
# pardoners
# juglandin
# shaggiest
# epipharyngeal
# predestines
# overcoated
# empale
# comprisal
# faying
# cetene
# glycerined
# zibeth
# archiepiscopates
# connectedly
# Saxonist
# glycosine
# sulphuration
# spiritualising
# histrionical
# densimeter
# tramble
# korred
# eudiometry
# disregardful
# ricochetted
# scioptic
# trawlnet
# martite
# bolographic
# afterclap
# sublimities
# needlecases
# skanked
# haematogenous
# entosthoblast
# glutin
# sufflate
# imploration
# cheesies
# phototonus
# nardo
# impark
# bouse
# rhinoplastic
# phanerocrystalline
# clevernesses
# diatessaron
# brachydactylic
# fulgurous
# narcotise
# workboard
# picketted
# throttler
# thermotaxic
# sclerobase
# lobulette
# rantipole
# corybantiasm
# callousing
# mystagogic
# dight
# sturt
# truanted
# phlegmonous
# mucosas
# spermatin
# haggadoth
# synanthous
# anear
# dissatisfies
# interjacent
# hydrogalvanic
# euphonize
# wrey
# prongy
# smirches
# lamelliform
# stigmaria
# arthropodan
# Pehlevi
# chrysene
# bottomer
# assenter
# gumwood
# foetation
# doncella
# globulous
# meralgia
# spiritous
# tamis
# octette
# extraprofessional
# umbraculiform
# cerebrology
# mylodon
# spewer
# diclinic
# endomorph
# monachal
# tautening
# platitudinal
# typhomalarial
# jutlandish
# zincographer
# carbineer
# percarbide
# circumscriptively
# transpirable
# pluckings
# Lyginopteris
# alchemizes
# brandisher
# commensurably
# deforciant
# Pelecypoda
# astrography
# zoogloea
# scintillas
# dradge
# circumferentor
# hypotyposis
# astriction
# vincentian
# coag
# restively
# subcarboniferous
# hemstitched
# infralapsarian
# acrimonies
# saltcellar
# hoodooing
# desorbs
# gastrocolic
# nycthemeron
# revolter
# approbative
# importancy
# christianite
# quinoidine
# stour
# vitrella
# histohaematin
# myotomes
# logogrammatically
# hobit
# psalterium
# barrelfuls
# imbitterer
# bigeminate
# allower
# sweal
# unguinous
# tablers
# gonfanon
# immiting
# subdeanery
# suability
# pylangium
# demilune
# purgery
# tetter
# boatered
# butching
# insusceptibility
# confiscator
# bicostate
# polyphagy
# thetis
# decalcomanie
# blastoidea
# fruitlet
# lobated
# antimonite
# torpescence
# valeramide
# perspicuousness
# invocatory
# goitrous
# xiphophyllous
# antaphrodisiac
# melitose
# vacciniums
# electricities
# criminates
# fluentness
# chalazal
# prosaism
# periodoscope
# nematoidea
# Puseyite
# bleck
# coinsure
# saibling
# paludina
# nebulose
# lithiophilite
# disavower
# ament
# stocktaker
# allowedly
# opisthorchiasis
# rinsings
# hotters
# semicentenary
# chirographic
# pauropoda
# walkmen
# briered
# undersizing
# allegorizer
# evincible
# mesogastric
# hymeneal
# promptbook
# nuncupate
# mycophagist
# prophetesss
# adune
# circumflexion
# technicalness
# shelflike
# frazzles
# dandler
# peorias
# mannitose
# naze
# chargeing
# ureal
# dipodies
# glibbest
# dowagerism
# penitencer
# beadroll
# podobranchia
# caies
# alphabetism
# fahlband
# shamois
# jasey
# decreeable
# shalloon
# crotonylene
# triparted
# Tsting
# lucimeter
# genappe
# writative
# autarchical
# pervertible
# morphinism
# embrowned
# muckiest
# unfathered
# superadd
# alcade
# abought
# munding
# spoilter
# disunify
# pontlevis
# curvedness
# nodosity
# deflowers
# caprioling
# ceremonialness
# hoggish
# bendability
# undercoats
# viraginity
# shiksas
# remolade
# camise
# legislatorial
# incurvating
# dentigerous
# spotteds
# millivoltmeter
# modocs
# balistraria
# hewkins
# choriambus
# prehallux
# hypophosphorous
# bromize
# unmoor
# tuaregs
# swink
# scotograph
# dentated
# locusta
# thraw
# Oped
# drib
# diacaustic
# vellon
# exegetics
# metatungstate
# disploded
# catastasis
# demonolatry
# woolliest
# hoving
# proselyted
# unijugate
# pilgarlic
# interlope
# commemoratory
# friezer
# wokking
# xylophilous
# dialogistical
# subpulmonary
# knackwurst
# bossage
# cerous
# scarabee
# barbiers
# statued
# bergander
# disanoint
# pustulate
# gobful
# poecilitic
# lacertid
# annealer
# polystome
# perorating
# voltaism
# melodise
# shelfful
# shippings
# mazourka
# unshrinkable
# entitative
# bluecoat
# hydrophobias
# pustulent
# tumulter
# rhinencephala
# hematolysis
# georgic
# demineralize
# Macacus
# pisciculturist
# chatterings
# dipetalous
# cyclopedist
# scrow
# truthless
# salimetry
# sceneman
# lophius
# conferrable
# generalness
# fellowshiped
# unimpressionable
# cawk
# wackadoo
# libercarelessian
# Maslins
# protuberate
# tetradont
# cytode
# flowings
# reappropriates
# parelectronomic
# hemapophysis
# tannage
# palus
# paragogical
# cony
# spectatress
# yieldance
# volapuk
# barmaster
# concussing
# opiner
# kerneling
# apotheosised
# iding
# softa
# sesban
# traditionaries
# tweeded
# transubstantiate
# lawsonia
# skitty
# solano
# teleosaurus
# sharpenings
# ragman
# centrode
# triumpher
# spontaneousness
# gastroduodenitis
# bedraggle
# omostegite
# radiculitis
# transfusive
# disimprove
# snafues
# perissad
# undecylenic
# Stms
# clustery
# dallier
# bespattering
# liquefacient
# brawned
# obdiplostemony
# bedwarfed
# bittock
# ganoine
# cresorcin
# demonomania
# shawnees
# dutchmen
# mundungus
# panetella
# decolorate
# deposer
# enfeebler
# uncage
# willowish
# creosotes
# Hudibrastic
# recrementitious
# skiffling
# palama
# quiescing
# pharmacosiderite
# lepidote
# dowdiest
# planoblast
# caughts
# brewsterite
# pluging
# menology
# asonant
# scrappings
# disobliger
# xanthin
# tallowing
# sinistrously
# laurus
# wheyface
# nowel
# sandpapers
# hydrosulphide
# Dipteryx
# uropod
# spoliative
# inimitability
# tenpenny
# crambo
# testudinated
# curacoa
# gooned
# shrewishness
# poleaxeing
# letterless
# counterpoison
# quartzoid
# tubulose
# phlorizin
# hebraizing
# muscadel
# drupel
# vibrion
# whortle
# enamor
# triplexer
# extenuator
# somnambulists
# tumbledung
# synteretic
# slatternliness
# sclaffs
# perigynium
# mariticide
# westerlys
# periscoped
# imbosoming
# portance
# outroot
# microwait
# newing
# gingerbreads
# inspanning
# braky
# curliest
# deracinate
# cyphered
# esterifies
# caughts
# emends
# traducingly
# timepleaser
# myrtiform
# disheritor
# inveiglement
# malinois
# contignation
# palpatory
# butment
# witherings
# toused
# chthonophagy
# cognovit
# diaphanometer
# tl;dr
# milords
# papula
# ghostwrites
# willowing
# torturingly
# reticences
# monecious
# submerses
# effronteries
# ungrave
# gladdest
# inerrable
# underlease
# bodian
# trubs
# swingle
# arbute
# insociability
# musculation
# allegorizers
# mistful
# actinograph
# resorter
# diiodide
# counterfort
# encrustment
# strigils
# dinkys
# maladdress
# heptavalent
# cohobate
# naturalises
# potterer
# presphenoid
# spiritlessness
# lepidosiren
# circumventor
# culpabilities
# blearing
# estranger
# believingly
# unguiculated
# congees
# firebacks
# pastorage
# metiers
# intermits
# aviating
# souses
# gooned
# urocystis
# nourishable
# carposporic
# hematogenic
# jumbler
# xenyl
# auriculae
# seamanly
# aphyllous
# windflowers
# dandled
# malacoderm
# Calvers
# filaceous
# sebesten
# inexpiably
# cirsotomy
# catkinate
# crossruff
# pandanaceae
# crunode
# moodys
# opsonized
# pentacid
# planations
# Harliano
# laudator
# mesoarium
# plumbaginous
# albertite
# scutellated
# decumbiture
# kinology
# unregenerated
# farcing
# splanchnapophysis
# tinniest
# glycolyl
# inductometer
# eloignment
# dermestes
# precrural
# dornock
# willywaw
# deviling
# rambutans
# tabored
# laniard
# soapier
# dannebrog
# collinsia
# abdest
# potica
# ecphractic
# hypogene
# roisterers
# phylloxanthin
# clinoid
# wavings
# abatic
# somnipathy
# Parsiism
# charpie
# petaurist
# arthritical
# dyspepsy
# moldiness
# brutify
# theorematical
# Aams
# esteemable
# redhibition
# meerschaums
# ungratified
# Genoas
# engrain
# intercolumniation
# cully
# musculospiral
# demagog
# siphonata
# oolites
# birdnesting
# infamousness
# thrummy
# FRANKS
# Characeae
# abashing
# tartareous
# feazing
# musicomania
# Anglomaniac
# subtilizing
# predeterminate
# electioneerer
# cinematize
# ovicapsule
# getatable
# victualing
# sulcated
# tepidness
# replenisher
# cardings
# buzzings
# dobleing
# mongrelizing
# axillaries
# toller
# hepatoscopy
# remigration
# verderor
# soothly
# queasiest
# blunge
# clapperclaws
# rhinoscleroma
# ambassage
# unsteel
# immission
# uprush
# eternalize
# thingumajig
# pellmell
# urohyal
# mooner
# confrontment
# arborized
# shopboard
# sterned
# disciplinal
# quatercentennial
# ochroleucous
# deprecative
# insnaring
# outwrite
# videorecorders
# bloting
# meanhead
# denunciator
# heroicomic
# prenominate
# Cynwulf
# ratiocinating
# conchoids
# marplot
# adjures
# denotatum
# oos
# vibed
# countermining
# viragoes
# adhereing
# thessalians
# metaphosphoric
# wheezily
# enantiopathy
# avel
# glossology
# flankered
# thomsonite
# attemptable
# odontograph
# albertype
# gynaecium
# verisimilar
# sparges
# flushings
# saccharic
# waverer
# qualifiedly
# hierographic
# flumping
# sternebra
# abasia
# notecase
# widowly
# octodecimo
# trippings
# haversian
# uroxanic
# alcoranist
# gingle
# bulletined
# scarifies
# ruddles
# salifiable
# gurglings
# abraxas
# bestialise
# luggaged
# courtliest
# pulverulence
# fleers
# incage
# postiled
# neologize
# jumpiest
# puniest
# omphalomesenteric
# fastigiated
# steem
# morindin
# dioeciously
# regma
# neomorph
# victress
# cooperages
# dissidently
# hymenia
# tabbying
# orlo
# vastnesses
# oneida
# guerite
# spilikins
# arboriculturist
# concentering
# decalcify
# scumbling
# thunderstriking
# caligo
# cantharidal
# coversed
# anophelines
# Calliopes
# blickey
# siderographic
# slickens
# matronhood
# erythrodextrin
# screechings
# intussuscepts
# imping
# novelise
# aweather
# incult
# aurate
# coenurus
# ammonifies
# pissings
# megafarad
# unoiled
# pneumatical
# pothooks
# benthamism
# transeunt
# disaffirmance
# indispensableness
# interseptal
# lentissimo
# pinnulate
# 754it [00:00, 7536.31it/s]
# soggiest
# polyphonous
# displeasingly
# inscient
# outride
# sensualization
# socmen
# institutively
# Brotulidae
# coadapted
# bottomry
# weathercocking
# tinger
# chronologer
# stroam
# veinlet
# uneath
# kerite
# chaws
# pharmacon
# bemuddle
# generability
# indisposes
# antonomastic
# pyrographer
# hobbledehoy
# infusibility
# dolabra
# leisureliness
# savorys
# stalest
# pedestrianizing
# notturnos
# clubhaul
# geogony
# oxymel
# proglottides
# ethylidene
# heteroplastic
# undecked
# chandelled
# dupper
# spoonfeeds
# anelectrode
# concentrical
# inchmeal
# peripatetics
# towropes
# rhizoma
# intonates
# budger
# orchidalgia
# countryfied
# spontoon
# cerolite
# mauritanians
# periled
# picotee
# blindfish
# Atherinidae
# cheapjacks
# gravelling
# extirpative
# 29171it [00:02, 13381.12it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4b04810e5004> in <module>
#      14 sub_fasttext_dict.update(high_freq_dict)
#      15
# ---> 16 vocab = VocabEntry.from_corpus(src_sents, 1000000, 0)
#      17
#      18 print(len(vocab))
#
# NameError: name 'src_sents' is not defined

# %%
vocab = VocabEntry.from_corpus(definitions, 1000000, 0)
for w in words:
    vocab.add(w)
print(len(vocab))
# Out:
# number of word types: 46021, number of word types w/ frequency >= 0: 46021
# 98418

# %%
import pickle
with open("../data/words_definitions_sub_fasttext_dict.train", "wb") as f:
    pickle.dump((words, definitions, sub_fasttext_dict), f)

# %%
assert(len(words) == len(definitions))
training_data = [(definitions[i], words[i]) for i in range(len(words))]

# %%
def create_emb_layer(weights_matrix, src_pad_token_idx, non_trainable=False):
    num_embeddings, embedding_dim = weights_matrix.shape
    emb_layer = nn.Embedding(num_embeddings, embedding_dim, src_pad_token_idx)
    emb_layer.weight.data.copy_(torch.from_numpy(weights_matrix)) #figure out what is here
    if non_trainable:
        emb_layer.weight.requires_grad = False
    return emb_layer, num_embeddings, embedding_dim

class ModelEmbeddings(nn.Module): 
    """
    Class that converts input words to their embeddings.
    """

    def __init__(self, embed_size, vocab, fasttext_dict):
        """
        Init the Embedding layers.

        @param embed_size (int): Embedding size (dimensionality)
        @param vocab (VocabEntry)
        """
        super(ModelEmbeddings, self).__init__()

        self.embed_size = embed_size

        matrix_len = len(vocab)
        weights_matrix = np.zeros((matrix_len, self.embed_size))
        words_found = 0
        #print(len(vocab), weights_matrix.shape)
        for word, index in vocab.word2id.items():
            try:
                weights_matrix[index] = np.array(fasttext_dict[word])
                words_found += 1
            except KeyError:
                weights_matrix[index] = np.random.normal(scale=0.6, size=(self.embed_size,))

        # default values
        src_pad_token_idx = vocab['<pad>']
        self.source = create_emb_layer(weights_matrix, src_pad_token_idx, True)

# %%
# class GRUModel(nn.Module):
#     def __init__(self, input_size, hidden_size, vocab, fasttext_dict):
#         super(GRUModel, self).__init__()
#         self.hidden_size = hidden_size
#         self.embedding = ModelEmbeddings(input_size, vocab, fasttext_dict)
#         self.gru = nn.GRU(input_size, hidden_size)
        
#         self.linear = nn.Linear(self.hidden_size, self.hidden_size, bias = True)

#     def forward(self, input_, hidden, lengths , dropout_rate = 0.3):
#         embedded = self.embedding.source[0](input_)
#         embedded = pack_padded_sequence(embedded, lengths)
#         output, hidden = self.gru(embedded, hidden)
#         dropout = nn.Dropout(dropout_rate)
#         hidden_dropped = dropout(hidden.permute(1,0,2)) # you dont need dropout in validation
#         projected = self.linear(hidden_dropped)
#         return projected, hidden

#     def initHidden(self, batch_size, device = None):
#         return torch.zeros(1, batch_size, self.hidden_size, device=device)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, vocab, fasttext_dict):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.vocab = vocab
        self.embedding = ModelEmbeddings(input_size, vocab, fasttext_dict)
        self.lstm = nn.LSTM(input_size, hidden_size, bidirectional = True)
        self.linear = nn.Linear(self.hidden_size * 2, self.hidden_size, bias = True)

    def forward(self, input_, hidden, lengths , dropout_rate = 0.3):
        embedded = self.embedding.source[0](input_)
        embedded = pack_padded_sequence(embedded, lengths)
        output, (h_n, c_n) = self.lstm(embedded)
        #print(h_n.shape, c_n.shape)
        dropout = nn.Dropout(dropout_rate)
        hidden_dropped = dropout(h_n.contiguous().view(1, -1, self.hidden_size * 2).permute(1,0,2)) # you dont need dropout in validation
        projected = self.linear(hidden_dropped)
        return projected, hidden

    def initHidden(self, batch_size, device = None):
        return torch.zeros(1, batch_size, self.hidden_size, device=device)

# %%
model = LSTMModel(300, 300, vocab, fasttext_dict)
loss_function = nn.CosineEmbeddingLoss(margin=0.0, reduction='sum')
optimizer = torch.optim.Adagrad(model.parameters(), lr = 0.1)

# %%
# model = GRUModel(50, 50, vocab, fasttext_dict)
# loss_function = nn.L1Loss(reduction = "sum")
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.999))

# %%
# #check overfit

# definition_indices = vocab.words2indices(definitions)
# words_in = 0
# words_out = 0

# import timeit
# start = timeit.default_timer()
# losses = []

# batch_size = 128

# for src_sents, tgt_word in batch_iter(training_data, batch_size, False):
#     for i in range(300):
#         model.zero_grad()
#         x_lengths = [len(sent) for sent in src_sents]
#         x = vocab.to_input_tensor(src_sents, "cpu")
#         init_hidden = model.initHidden(len(src_sents), "cpu")
#         tag_scores = model.forward(x, init_hidden, x_lengths)
#         y_array = model.embedding.source[0](torch.tensor(vocab.words2indices(tgt_word))).double()
#         y_pred = tag_scores[0].squeeze(dim = 1).double()
#         loss = loss_function(y_pred, y_array, torch.tensor(1))
#         loss.backward()
#         optimizer.step() 
#         losses.append(loss)
#         if i % 10 == 0:
#             print(i, loss)
#     break
    
# stop = timeit.default_timer()

# print('Time: ', stop - start)

# import matplotlib.pyplot as plt
# print(plt.plot([l.double() for l in losses][:1200]))

# model.zero_grad()
# x_lengths = [len(sent) for sent in src_sents]
# x = vocab.to_input_tensor(src_sents, "cpu")
# init_hidden = model.initHidden(len(src_sents), "cpu")
# tag_scores = model.forward(x, init_hidden, x_lengths)
# y_pred = tag_scores[0].squeeze(dim = 1).double()

# validate_dict = dict([(w, model.embedding.source[0](torch.tensor(vocab[w])).numpy()) for w in set(words)])
# print(len(validate_dict))

# print(y_pred.shape)
# for i in range(len(y_pred)):
#     eval.top_ten_hundred(validate_dict, tgt_word[i], y_pred[i].detach().numpy())
# Out:
# 0 tensor(658.6178, dtype=torch.float64, grad_fn=<SumBackward0>)
# 10 tensor(491.0352, dtype=torch.float64, grad_fn=<SumBackward0>)
# 20 tensor(483.5285, dtype=torch.float64, grad_fn=<SumBackward0>)
# 30 tensor(474.5168, dtype=torch.float64, grad_fn=<SumBackward0>)
# 40 tensor(462.6443, dtype=torch.float64, grad_fn=<SumBackward0>)
# 50 tensor(446.3719, dtype=torch.float64, grad_fn=<SumBackward0>)
# 60 tensor(427.2912, dtype=torch.float64, grad_fn=<SumBackward0>)
# 70 tensor(408.6536, dtype=torch.float64, grad_fn=<SumBackward0>)
# 80 tensor(391.3982, dtype=torch.float64, grad_fn=<SumBackward0>)
# 90 tensor(369.7998, dtype=torch.float64, grad_fn=<SumBackward0>)
# 100 tensor(338.1760, dtype=torch.float64, grad_fn=<SumBackward0>)
# 110 tensor(333.5540, dtype=torch.float64, grad_fn=<SumBackward0>)
# 120 tensor(302.0123, dtype=torch.float64, grad_fn=<SumBackward0>)
# 130 tensor(294.8869, dtype=torch.float64, grad_fn=<SumBackward0>)
# 140 tensor(261.7060, dtype=torch.float64, grad_fn=<SumBackward0>)
# 150 tensor(247.8166, dtype=torch.float64, grad_fn=<SumBackward0>)
# 160 tensor(237.1650, dtype=torch.float64, grad_fn=<SumBackward0>)
# 170 tensor(222.3569, dtype=torch.float64, grad_fn=<SumBackward0>)
# 180 tensor(212.8500, dtype=torch.float64, grad_fn=<SumBackward0>)
# 190 tensor(206.2448, dtype=torch.float64, grad_fn=<SumBackward0>)
# 200 tensor(194.4763, dtype=torch.float64, grad_fn=<SumBackward0>)
# 210 tensor(186.1295, dtype=torch.float64, grad_fn=<SumBackward0>)
# 220 tensor(179.2815, dtype=torch.float64, grad_fn=<SumBackward0>)
# 230 tensor(174.5262, dtype=torch.float64, grad_fn=<SumBackward0>)
# 240 tensor(171.2396, dtype=torch.float64, grad_fn=<SumBackward0>)
# 250 tensor(163.8036, dtype=torch.float64, grad_fn=<SumBackward0>)
# 260 tensor(161.2974, dtype=torch.float64, grad_fn=<SumBackward0>)
# 270 tensor(158.2163, dtype=torch.float64, grad_fn=<SumBackward0>)
# 280 tensor(153.3062, dtype=torch.float64, grad_fn=<SumBackward0>)
# 290 tensor(153.3504, dtype=torch.float64, grad_fn=<SumBackward0>)
# Time:  395.1882130539743
# [<matplotlib.lines.Line2D object at 0x1a26bcf3c8>]
# 82771
# torch.Size([1024, 300])
# ['lion', 'lions', 'lioness', 'tiger', 'lionesses', 'elephant', 'leopard', 'dragon', 'beast', 'tusker']
# lion ['lion', 'lions', 'lioness', 'tiger', 'lionesses', 'elephant', 'leopard', 'dragon', 'beast', 'tusker']
# ['scene', 'scenes', 'reenacts', 'video', 'filmdom', 'film', 'sequence', 'story', 'stage', 'picture']
# scene ['scene', 'scenes', 'reenacts', 'video', 'filmdom', 'film', 'sequence', 'story', 'stage', 'picture']
# ['rape', 'rapes', 'raper', 'murder', 'raping', 'raped', 'violence', 'theft', 'rapist', 'incest']
# rape ['rape', 'rapes', 'raper', 'murder', 'raping', 'raped', 'violence', 'theft', 'rapist', 'incest']
# ['unbelieving', 'unbeliever', 'feeing', 'unbelievers', 'unseeing', 'unbelief', 'unloving', 'disbelieving', 'laming', 'godless']
# unbelieving ['unbelieving', 'unbeliever', 'feeing', 'unbelievers', 'unseeing', 'unbelief', 'unloving', 'disbelieving', 'laming', 'godless']
# ['dessert', 'cheesecake', 'potpie', 'snack', 'foodless', 'pralines', 'snacks', 'chocolate', 'quiches', 'cake']
# dessert ['dessert', 'cheesecake', 'potpie', 'snack', 'foodless', 'pralines', 'snacks', 'chocolate', 'quiches', 'cake']
# ['affray', 'affrays', 'assault', 'occasioning', 'brawl', 'brawls', 'fisticuffs', 'brawling', 'exeat', 'revelry']
# affray ['affray', 'affrays', 'assault', 'occasioning', 'brawl', 'brawls', 'fisticuffs', 'brawling', 'exeat', 'revelry']
# ['probe', 'probes', 'probed', 'probing', 'investigate', 'uncover', 'probings', 'examine', 'investigation', 'discover']
# probe ['probe', 'probes', 'probed', 'probing', 'investigate', 'uncover', 'probings', 'examine', 'investigation', 'discover']
# ['beens', 'hads', 'goners', 'sooks', 'diddled', 'wone', 'tooks', 'crapped', 'mads', 'rooked']
# beens ['beens', 'hads', 'goners', 'sooks', 'diddled', 'wone', 'tooks', 'crapped', 'mads', 'rooked']
# ['decomposition', 'decomposing', 'decompositions', 'humification', 'decompose', 'recomposition', 'decomposes', 'decomposed', 'carbonization', 'putrefaction']
# decomposition ['decomposition', 'decomposing', 'decompositions', 'humification', 'decompose', 'recomposition', 'decomposes', 'decomposed', 'carbonization', 'putrefaction']
# ['wassail', 'wassailing', 'brose', 'cruet', 'quaich', 'specked', 'calabashes', 'shoofly', 'plash', 'burred']
# wassail ['wassail', 'wassailing', 'brose', 'cruet', 'quaich', 'specked', 'calabashes', 'shoofly', 'plash', 'burred']
# ['ageratum', 'groundsel', 'sapota', 'dianthus', 'polyanthus', 'viburnums', 'pinus', 'aurelia', 'chickweed', 'petrolatum']
# ageratum ['ageratum', 'groundsel', 'sapota', 'dianthus', 'polyanthus', 'viburnums', 'pinus', 'aurelia', 'chickweed', 'petrolatum']
# ['housing', 'residential', 'accommodation', 'employment', 'rehousing', 'building', 'health', 'education', 'house', 'shelter']
# housing ['housing', 'residential', 'accommodation', 'employment', 'rehousing', 'building', 'health', 'education', 'house', 'shelter']
# ['arms', 'arm', 'armaments', 'weapons', 'armouries', 'armies', 'armours', 'armigers', 'maces', 'bucklers']
# arms ['arms', 'arm', 'armaments', 'weapons', 'armouries', 'armies', 'armours', 'armigers', 'maces', 'bucklers']
# ['exogenous', 'endogenous', 'exogenic', 'endogenic', 'endogenously', 'systemic', 'semisynthetic', 'estrogenic', 'antineoplastic', 'lysogenic']
# exogenous ['exogenous', 'endogenous', 'exogenic', 'endogenic', 'endogenously', 'systemic', 'semisynthetic', 'estrogenic', 'antineoplastic', 'lysogenic']
# ['bound', 'pinioned', 'bounded', 'scaped', 'meak', 'pilled', 'shacked', 'coshed', 'unbound', 'distrained']
# bound ['bound', 'pinioned', 'bounded', 'scaped', 'meak', 'pilled', 'shacked', 'coshed', 'unbound', 'distrained']
# ['northwest', 'southwest', 'northeast', 'southeast', 'north', 'west', 'east', 'south', 'northwestern', 'southeastern']
# northwest ['northwest', 'southwest', 'northeast', 'southeast', 'north', 'west', 'east', 'south', 'northwestern', 'southeastern']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-4e2a626745a8> in <module>
#      47 print(y_pred.shape)
#      48 for i in range(len(y_pred)):
# ---> 49     eval.top_ten_hundred(validate_dict, tgt_word[i], y_pred[i].detach().numpy())
#
# ~/Development/Dict2Word/model/evaluator.py in top_ten_hundred(self, embeddings_dict, answer, guess)
#      64         """
#      65         self.th_tracker['count'] += 1
# ---> 66         top_hundred = self.find_closest_embeddings(embeddings_dict, guess, k = 100)
#      67         top_ten = top_hundred[:10]
#      68         if answer in top_ten:
#
# ~/Development/Dict2Word/model/evaluator.py in find_closest_embeddings(self, embeddings_dict, embedding, k)
#      52         """
#      53         ans = sorted(embeddings_dict.keys(),
# ---> 54                       key=lambda word: spatial.distance.cosine(embeddings_dict[word], embedding))
#      55         print(ans[:10])
#      56
#
# ~/Development/Dict2Word/model/evaluator.py in <lambda>(word)
#      52         """
#      53         ans = sorted(embeddings_dict.keys(),
# ---> 54                       key=lambda word: spatial.distance.cosine(embeddings_dict[word], embedding))
#      55         print(ans[:10])
#      56
#
# ~/opt/miniconda3/envs/local_nmt/lib/python3.5/site-packages/scipy/spatial/distance.py in cosine(u, v, w)
#     742     # cosine distance is also referred to as 'uncentered correlation',
#     743     #   or 'reflective correlation'
# --> 744     return correlation(u, v, w=w, centered=False)
#     745
#     746
#
# ~/opt/miniconda3/envs/local_nmt/lib/python3.5/site-packages/scipy/spatial/distance.py in correlation(u, v, w, centered)
#     696     uu = np.average(np.square(u), weights=w)
#     697     vv = np.average(np.square(v), weights=w)
# --> 698     dist = 1.0 - uv / np.sqrt(uu * vv)
#     699     return dist
#     700
#
# KeyboardInterrupt:

# %%
definition_indices = vocab.words2indices(definitions)
words_in = 0
words_out = 0

import timeit
start = timeit.default_timer()
losses = []

batch_size = 16

for epoch in range(500):
    print(epoch, loss, timeit.default_timer() - start)
    for src_sents, tgt_word in batch_iter(training_data[:int(len(training_data)/3)], batch_size, False):
        model.zero_grad()
        x_lengths = [len(sent) for sent in src_sents]
        x = vocab.to_input_tensor(src_sents, "cpu")
        init_hidden = model.initHidden(len(src_sents), "cpu")
        tag_scores = model.forward(x, init_hidden, x_lengths)
        y_array = model.embedding.source[0](torch.tensor(vocab.words2indices(tgt_word))).double()
        y_pred = tag_scores[0].squeeze(dim = 1).double()
        loss = loss_function(y_pred, y_array, torch.tensor(1))
        loss.backward()
        optimizer.step() 
    losses.append(loss)
    
    
stop = timeit.default_timer()

print('Time: ', stop - start)

import matplotlib.pyplot as plt
print(plt.plot([l.double() for l in losses]))
# Out:
# 0 tensor(8.0837, dtype=torch.float64, grad_fn=<SumBackward0>) 0.000351533992215991
# 1 tensor(1.8738, dtype=torch.float64, grad_fn=<SumBackward0>) 333.7174669940723
# 2 tensor(1.8759, dtype=torch.float64, grad_fn=<SumBackward0>) 658.0808797510108
# 3 tensor(1.8644, dtype=torch.float64, grad_fn=<SumBackward0>) 1050.2992318719625
# 4 tensor(1.8642, dtype=torch.float64, grad_fn=<SumBackward0>) 1387.8593751060544
# 5 tensor(1.8622, dtype=torch.float64, grad_fn=<SumBackward0>) 1696.1548831410473
# 6 tensor(1.8613, dtype=torch.float64, grad_fn=<SumBackward0>) 2046.6296234959736
# 7 tensor(1.8522, dtype=torch.float64, grad_fn=<SumBackward0>) 2411.996872395044
# 8 tensor(1.8609, dtype=torch.float64, grad_fn=<SumBackward0>) 2658.9843309830176
# 9 tensor(1.8574, dtype=torch.float64, grad_fn=<SumBackward0>) 2896.2523295070278
# 10 tensor(1.8508, dtype=torch.float64, grad_fn=<SumBackward0>) 3131.597627618001
# 11 tensor(1.8572, dtype=torch.float64, grad_fn=<SumBackward0>) 3366.463730272022
# 12 tensor(1.8505, dtype=torch.float64, grad_fn=<SumBackward0>) 3673.7601303929696

# %%
import matplotlib.pyplot as plt
print(plt.plot([l.double() for l in losses]))

# %%
model.zero_grad()
x_lengths = [len(sent) for sent in src_sents]
x = vocab.to_input_tensor(src_sents, "cpu")
init_hidden = model.initHidden(len(src_sents), "cpu")
tag_scores = model.forward(x, init_hidden, x_lengths)
y_pred = tag_scores[0].squeeze(dim = 1).double()

validate_dict = dict([(w, model.embedding.source[0](torch.tensor(vocab[w])).detach().numpy()) for w in set(words)])
print(len(validate_dict))

print(y_pred.shape)
for i in range(len(y_pred)):
    eval.top_ten_hundred(validate_dict, tgt_word[i], y_pred[i].detach().numpy())
