# %%
import numpy as np
from collections import namedtuple
import sys
from typing import List, Tuple, Dict, Set, Union
import torch
import torch.nn as nn
import torch.nn.utils
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence
from nltk import word_tokenize

#from model_embeddings import ModelEmbeddings
from evaluator import Evaluator
from vocab import Vocab, VocabEntry
from utils import read_corpus, pad_sents, batch_iter
# Out:
# [nltk_data] Downloading package punkt to /Users/yuloucn/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
definitions = []
unparsed_definition = []
words = []
src_sents = read_corpus('../data/data_train_definitions.txt')

# %%
with open('../data/data_train_words.txt') as f:
    words += f.read().splitlines()
    
with open('../data/data_train_definitions.txt') as f:
    unparsed_definition += f.read().splitlines()
    definitions += [word_tokenize(a) for a in unparsed_definition]

training_data = [(definitions[i], words[i]) for i in range(len(words))]

# %%
eval = Evaluator()
glove_dict = eval.load_glove_embeddings(max_line = 10000000)
sub_glove_dict = {}
#only train words in the dictionary
for i in range(len(words)-1, -1, -1):
    if words[i] not in glove_dict:
        print(words[i])
        words.pop(i)
        definitions.pop(i)
    else:
        sub_glove_dict[words[i]] = glove_dict[words[i]]
        
high_freq_dict = eval.load_glove_embeddings(max_line = 30000)
sub_glove_dict.update()

src_sents = read_corpus('../data/data_train_definitions.txt')
vocab = VocabEntry.from_corpus(src_sents, 1000000, 0)
    
print(len(vocab))
# Out:
# pyrogenic
# pyrogenic
# pyrogenic
# pyrogenic
# throe
# throe
# throe
# throe
# throe
# throe
# throe
# throe
# throe
# throe
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# nauseate
# effulgence
# effulgence
# effulgence
# effulgence
# effulgence
# effulgence
# pensiveness
# pensiveness
# pensiveness
# pensiveness
# pensiveness
# calisthenic
# calisthenic
# comeliness
# comeliness
# disheartenment
# disheartenment
# disheartenment
# disheartenment
# disheartenment
# carminative
# carminative
# carminative
# carminative
# carminative
# dissatisfactory
# dissatisfactory
# dissatisfactory
# dissatisfactory
# dissatisfactory
# enervation
# enervation
# enervation
# enervation
# enervation
# enervation
# defalcation
# defalcation
# defalcation
# defalcation
# defalcation
# defalcation
# defalcation
# defalcation
# prestidigitator
# prestidigitator
# prestidigitator
# inclemency
# inclemency
# inclemency
# inclemency
# inclemency
# inclemency
# inclemency
# inclemency
# inclemency
# inclemency
# manganite
# manganite
# manganite
# manganite
# slumberous
# slumberous
# slumberous
# slumberous
# slumberous
# slumberous
# unhorse
# unhorse
# unhorse
# unhorse
# lenity
# lenity
# lenity
# lenity
# lenity
# lenity
# lenity
# basely
# basely
# basely
# basely
# basely
# covetously
# covetously
# covetously
# covetously
# overdress
# overdress
# overdress
# overdress
# overdress
# adhesiveness
# adhesiveness
# adhesiveness
# adhesiveness
# decimeter
# decimeter
# decimeter
# reproducer
# reproducer
# reproducer
# unexpressive
# unexpressive
# unexpressive
# fomentation
# fomentation
# fomentation
# fomentation
# fomentation
# fomentation
# fomentation
# bosky
# bosky
# meagerness
# meagerness
# meagerness
# meagerness
# intercommunicate
# intercommunicate
# intercommunicate
# intercommunicate
# intercommunicate
# intercommunicate
# gallivant
# gallivant
# gallivant
# gallivant
# splasher
# splasher
# splasher
# splasher
# paronychia
# paronychia
# preponderate
# preponderate
# preponderate
# preponderate
# preponderate
# preponderate
# preponderate
# preponderate
# preponderate
# preponderate
# unfrequented
# unfrequented
# misapply
# misapply
# misapply
# misapply
# brininess
# brininess
# tearless
# tearless
# tearless
# tearless
# despicableness
# despicableness
# despicableness
# despicableness
# cleavable
# calcine
# calcine
# calcine
# calcine
# calcine
# calcine
# bounden
# bounden
# bounden
# bounden
# bounden
# bounden
# bounden
# bounden
# jollification
# jollification
# jollification
# jollification
# entr'acte
# entr'acte
# entr'acte
# entr'acte
# squashy
# squashy
# squashy
# squashy
# squashy
# fluidness
# fluidness
# fluidness
# fluidness
# serration
# serration
# serration
# serration
# serration
# individuate
# individuate
# individuate
# individuate
# individuate
# individuate
# bastardize
# bastardize
# bastardize
# bastardize
# bastardize
# bastardize
# bastardize
# bastardize
# caterwaul
# caterwaul
# harlotry
# harlotry
# harlotry
# harlotry
# foreshorten
# foreshorten
# foreshorten
# foreshorten
# terpsichorean
# terpsichorean
# terpsichorean
# showily
# showily
# showily
# showily
# showily
# showily
# animalism
# animalism
# animalism
# animalism
# perfecter
# perfecter
# perfecter
# perfecter
# perfecter
# perfecter
# unhallowed
# unhallowed
# unhallowed
# unhallowed
# unhallowed
# unhallowed
# unhallowed
# butterfingered
# butterfingered
# butterfingered
# butterfingered
# butterfingered
# gabble
# gabble
# gabble
# gabble
# gabble
# gabble
# gabble
# gabble
# gabble
# expostulate
# expostulate
# expostulate
# vagary
# vagary
# vagary
# vagary
# vagary
# asininity
# asininity
# asininity
# pertinacious
# pertinacious
# pertinacious
# pertinacious
# pertinacious
# pertinacious
# pertinacious
# pertinacious
# dunghill
# dunghill
# dunghill
# dunghill
# dunghill
# scrag
# scrag
# scrag
# scrag
# scrag
# scrag
# scrag
# scrag
# scrag
# nonsensitive
# nonsensitive
# nonsensitive
# nonsensitive
# phylactery
# phylactery
# phylactery
# sprightliness
# sprightliness
# sprightliness
# sprightliness
# sprightliness
# sprightliness
# sprightliness
# sprightliness
# sprightliness
# weaponed
# weaponed
# weaponed
# weaponed
# sorb
# sorb
# sorb
# sorb
# rosiness
# rosiness
# rosiness
# rosiness
# rosiness
# hoggish
# hoggish
# hoggish
# hoggish
# hoggish
# hoggish
# dissembler
# dissembler
# dissembler
# dastard
# dastard
# dastard
# dastard
# dastard
# dastard
# dastard
# edgeways
# edgeways
# edgeways
# edgeways
# edgeways
# disobliging
# disobliging
# disobliging
# disobliging
# snivel
# snivel
# snivel
# snivel
# snivel
# snivel
# snivel
# snivel
# snivel
# snivel
# snivel
# fortuity
# fortuity
# fortuity
# fortuity
# corruptness
# corruptness
# corruptness
# corruptness
# remittal
# remittal
# remittal
# remittal
# remittal
# remittal
# remittal
# catcall
# catcall
# wooer
# wooer
# wooer
# redolence
# redolence
# redolence
# redolence
# redolence
# extenuation
# extenuation
# extenuation
# extenuation
# extenuation
# extenuation
# extenuation
# effluence
# effluence
# effluence
# effluence
# effluence
# deflower
# deflower
# deflower
# deflower
# deflower
# deflower
# deflower
# deflower
# deflower
# solitariness
# solitariness
# solitariness
# imbed
# imbed
# imbed
# imbed
# beleaguer
# beleaguer
# beleaguer
# beleaguer
# beleaguer
# aggregative
# aggregative
# aggregative
# aggregative
# fleetly
# fleetly
# fleetly
# overshoe
# overshoe
# overshoe
# saintlike
# saintlike
# saintlike
# saintlike
# saintlike
# saintlike
# nutriment
# nutriment
# nutriment
# nutriment
# nutriment
# nutriment
# nutriment
# precipitant
# precipitant
# precipitant
# precipitant
# precipitant
# precipitant
# precipitant
# precipitant
# precipitant
# precipitant
# mischance
# mischance
# mischance
# mischance
# mischance
# chancre
# chancre
# chancre
# perambulator
# perambulator
# perambulator
# perambulator
# outwear
# outwear
# outwear
# outwear
# outwear
# outwear
# plower
# plower
# plower
# plower
# striation
# striation
# striation
# collocate
# collocate
# collocate
# collocate
# plumy
# plumy
# plumy
# plumy
# plumy
# prodrome
# prodrome
# prodrome
# prodrome
# noncontagious
# noncontagious
# noncontagious
# noncontagious
# tatter
# tatter
# tatter
# tatter
# queerly
# queerly
# queerly
# revivification
# revivification
# revivification
# revivification
# revivification
# engorge
# engorge
# engorge
# engorge
# engorge
# engorge
# engorge
# engorge
# cardiograph
# cardiograph
# cardiograph
# thereabout
# thereabout
# thereabout
# thereabout
# thereabout
# scoffer
# scoffer
# savageness
# savageness
# distributer
# distributer
# distributer
# distributer
# headstall
# headstall
# forcemeat
# scarify
# scarify
# scarify
# scarify
# scarify
# perfuse
# perfuse
# perfuse
# perfuse
# meanspirited
# meanspirited
# meanspirited
# meanspirited
# meanspirited
# meanspirited
# meanspirited
# meanspirited
# pigfish
# pigfish
# pigfish
# pigfish
# glauconite
# glauconite
# glauconite
# whoremonger
# whoremonger
# whoremonger
# whoremonger
# pyrometer
# pyrometer
# pyrometer
# hiccough
# hiccough
# hiccough
# hiccough
# jaggy
# jaggy
# jaggy
# jaggy
# jaggy
# hypothecate
# hypothecate
# hypothecate
# hypothecate
# hypothecate
# theorization
# theorization
# theorization
# surplusage
# surplusage
# surplusage
# surplusage
# securer
# securer
# securer
# securer
# securer
# securer
# securer
# securer
# securer
# reseat
# reseat
# reseat
# reseat
# reseat
# transfigure
# transfigure
# transfigure
# transfigure
# transfigure
# transfigure
# mentum
# mentum
# mentum
# bleb
# bleb
# bleb
# bleb
# enkindle
# enkindle
# enkindle
# enkindle
# enkindle
# enkindle
# enkindle
# enkindle
# grapnel
# grapnel
# grapnel
# grapnel
# grapnel
# grapnel
# grapnel
# sheeny
# sheeny
# sheeny
# sheeny
# sheeny
# sheeny
# diaphysis
# diaphysis
# diaphysis
# convolute
# convolute
# convolute
# convolute
# convolute
# manful
# manful
# manful
# manful
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# unbend
# devilry
# devilry
# devilry
# devilry
# devilry
# devilry
# arguer
# arguer
# arguer
# arguer
# boaster
# boaster
# boaster
# awing
# awing
# awing
# awing
# awing
# fulmination
# fulmination
# fulmination
# fulmination
# fulmination
# eyehole
# eyehole
# eyehole
# inhere
# inhere
# inhere
# inhere
# inhere
# inhere
# stableboy
# stableboy
# stableboy
# stableboy
# granulate
# granulate
# granulate
# granulate
# granulate
# granulate
# granulate
# jackanapes
# jackanapes
# jackanapes
# jackanapes
# jackanapes
# overstrain
# overstrain
# overstrain
# overstrain
# contumacious
# contumacious
# contumacious
# contumacious
# contumacious
# contumacious
# bedevilment
# bedevilment
# bedevilment
# fauteuil
# fauteuil
# fauteuil
# perverseness
# perverseness
# perverseness
# emersion
# emersion
# emersion
# emersion
# countervail
# countervail
# countervail
# countervail
# countervail
# countervail
# countervail
# muddiness
# muddiness
# muddiness
# muddiness
# muddiness
# muddiness
# muddiness
# mulish
# mulish
# mulish
# mulish
# whimsicality
# whimsicality
# whimsicality
# podgy
# podgy
# podgy
# roguery
# roguery
# roguery
# roguery
# roguery
# roguery
# roguery
# effulgent
# effulgent
# effulgent
# effulgent
# effulgent
# effulgent
# effulgent
# equanimous
# equanimous
# equanimous
# equanimous
# trueness
# trueness
# trueness
# trueness
# trueness
# trueness
# trueness
# trueness
# trueness
# trueness
# unguent
# unguent
# unguent
# overfeed
# overfeed
# overfeed
# ratable
# ratable
# ratable
# ratable
# astigmatic
# astigmatic
# horseweed
# horseweed
# horseweed
# horseweed
# horseweed
# horseweed
# tramper
# tramper
# tramper
# tramper
# tramper
# tramper
# sulkiness
# sulkiness
# sulkiness
# sulkiness
# sulkiness
# sulkiness
# inapposite
# inapposite
# inapposite
# seriatim
# seriatim
# seriatim
# seriatim
# seriatim
# eatable
# eatable
# eatable
# eatable
# eatable
# eatable
# eatable
# conclusiveness
# conclusiveness
# misapprehend
# misapprehend
# misapprehend
# lowness
# lowness
# lowness
# lowness
# lowness
# lowness
# poorness
# poorness
# poorness
# poorness
# suppliant
# suppliant
# suppliant
# suppliant
# suppliant
# suppliant
# suppliant
# suppliant
# suppliant
# corrugate
# corrugate
# corrugate
# corrugate
# corrugate
# corrugate
# corrugate
# onanism
# onanism
# onanism
# onanism
# rotundity
# rotundity
# rotundity
# rotundity
# rotundity
# rotundity
# rotundity
# rotundity
# handwheel
# handwheel
# handwheel
# handwheel
# greasiness
# greasiness
# greasiness
# inalterable
# inalterable
# inalterable
# inalterable
# footmark
# footmark
# footmark
# felly
# felly
# felly
# felly
# felly
# disgruntle
# disgruntle
# joggle
# joggle
# joggle
# joggle
# joggle
# joggle
# joggle
# joggle
# joggle
# joggle
# joggle
# joggle
# incommunicative
# incommunicative
# incommunicative
# incommunicative
# incommunicative
# incommunicative
# incommunicative
# enfeeble
# enfeeble
# enfeeble
# enfeeble
# enfeeble
# enfeeble
# dissatisfy
# dissatisfy
# dissatisfy
# dissatisfy
# imputable
# imputable
# imputable
# imputable
# imputable
# imputable
# imputable
# remise
# remise
# remise
# remise
# remise
# remise
# remise
# remise
# remise
# remise
# remise
# consultive
# consultive
# consultive
# consultive
# derange
# derange
# derange
# derange
# derange
# derange
# derange
# derange
# derange
# derange
# veneering
# veneering
# veneering
# veneering
# accordant
# accordant
# accordant
# accordant
# accordant
# accordant
# accordant
# accordant
# mightiness
# mightiness
# mightiness
# mightiness
# mightiness
# mightiness
# mightiness
# mightiness
# meliorate
# meliorate
# meliorate
# meliorate
# meliorate
# meliorate
# meliorate
# meliorate
# spile
# spile
# spile
# spile
# spile
# spile
# spile
# cajolery
# cajolery
# opprobrious
# opprobrious
# opprobrious
# opprobrious
# opprobrious
# opprobrious
# opprobrious
# opprobrious
# opprobrious
# litheness
# litheness
# litheness
# pother
# pother
# pother
# pother
# pother
# pother
# pother
# pother
# pother
# pother
# pother
# pother
# pother
# whop
# whop
# whop
# whop
# calumnious
# calumnious
# calumnious
# calumnious
# calumnious
# milksop
# incertitude
# incertitude
# incertitude
# brail
# brail
# brail
# brail
# inutility
# inutility
# inutility
# osculation
# osculation
# osculation
# osculation
# allopathy
# allopathy
# tropically
# tropically
# tropically
# tropically
# inapplicability
# inapplicability
# enfeeblement
# enfeeblement
# enfeeblement
# enfeeblement
# scurf
# scurf
# scurf
# scurf
# scurf
# scurf
# absoluteness
# absoluteness
# absoluteness
# absoluteness
# absoluteness
# absoluteness
# absoluteness
# trumpery
# trumpery
# trumpery
# trumpery
# trumpery
# trumpery
# trumpery
# trumpery
# trumpery
# becloud
# becloud
# becloud
# becloud
# countercheck
# countercheck
# countercheck
# countercheck
# countercheck
# countercheck
# countercheck
# countercheck
# countercheck
# countercheck
# abstainer
# abstainer
# abstainer
# abstainer
# intrepidly
# intrepidly
# intrepidly
# intrepidly
# drawee
# drawee
# elusion
# elusion
# elusion
# elusion
# elusion
# elusion
# unfertile
# unfertile
# unfertile
# unfertile
# knavery
# knavery
# knavery
# knavery
# knavery
# knavery
# knavery
# knavery
# perfervid
# perfervid
# perfervid
# perfervid
# perfervid
# fleshiness
# fleshiness
# fleshiness
# fleshiness
# fleshiness
# partaker
# partaker
# partaker
# tallness
# tallness
# tallness
# tallness
# tallness
# simpleness
# simpleness
# simpleness
# simpleness
# simpleness
# chirrup
# chirrup
# chirrup
# chirrup
# chirrup
# uprightly
# uprightly
# uprightly
# impracticability
# impracticability
# impracticability
# impracticability
# unmannerly
# unmannerly
# unmannerly
# unmannerly
# impalpable
# impalpable
# impalpable
# impalpable
# impalpable
# impalpable
# impalpable
# impalpable
# impalpable
# impalpable
# impalpable
# spirituous
# spirituous
# spirituous
# spirituous
# spirituous
# spirituous
# spirituous
# spirituous
# spirituous
# spirituous
# spirituous
# moroseness
# moroseness
# moroseness
# slub
# slub
# slub
# slub
# slub
# cogitation
# cogitation
# cogitation
# cogitation
# cogitation
# cogitation
# insensibly
# insensibly
# insensibly
# insensibly
# insensibly
# indefeasible
# indefeasible
# indefeasible
# unwonted
# unwonted
# unwonted
# unwonted
# unwonted
# unwonted
# unwonted
# unwonted
# unwonted
# anticipative
# anticipative
# doorsill
# doorsill
# doorsill
# cumbrous
# cumbrous
# cumbrous
# cumbrous
# cumbrous
# deprave
# deprave
# deprave
# deprave
# fructify
# fructify
# fructify
# fructify
# fructify
# fructify
# fructify
# pliancy
# pliancy
# pliancy
# raillery
# raillery
# raillery
# raillery
# raillery
# pulverization
# pulverization
# pulverization
# pulverization
# sectary
# sectary
# sectary
# sectary
# sectary
# sectary
# rubeola
# rubeola
# rubeola
# rubeola
# domiciliation
# domiciliation
# mucoid
# mucoid
# suppurative
# suppurative
# disfiguration
# disfiguration
# disfiguration
# disfiguration
# disfiguration
# audaciousness
# audaciousness
# audaciousness
# audaciousness
# audaciousness
# manlike
# manlike
# manlike
# manlike
# manlike
# telemeter
# telemeter
# telemeter
# slightness
# slightness
# slightness
# slightness
# slightness
# slightness
# slightness
# slightness
# slightness
# embossment
# embossment
# embossment
# embossment
# embossment
# embossment
# embossment
# embossment
# frowzy
# frowzy
# frowzy
# frowzy
# frowzy
# bootless
# bootless
# bootless
# bootless
# scraggy
# scraggy
# scraggy
# scraggy
# crimper
# crimper
# crimper
# profoundness
# profoundness
# profoundness
# profoundness
# profoundness
# engross
# engross
# engross
# engross
# engross
# engross
# engross
# engross
# engross
# deducible
# deducible
# deducible
# confabulate
# confabulate
# confabulate
# confabulate
# confabulate
# confabulate
# lodgment
# lodgment
# lodgment
# lodgment
# lodgment
# lodgment
# sluttish
# sluttish
# sluttish
# sluttish
# sluttish
# sluttish
# forsooth
# forsooth
# forsooth
# forsooth
# forsooth
# coronate
# coronate
# coronate
# coronate
# coronate
# veracious
# veracious
# veracious
# veracious
# veracious
# veracious
# veracious
# veracious
# mineralize
# mineralize
# mineralize
# mineralize
# mineralize
# mineralize
# carousal
# carousal
# carousal
# carousal
# carousal
# hypothetic
# hypothetic
# hypothetic
# hypothetic
# congeries
# congeries
# congeries
# congeries
# briefness
# briefness
# briefness
# briefness
# briefness
# presbyopic
# presbyopic
# pouter
# pouter
# pouter
# uncloak
# uncloak
# uncloak
# uncloak
# uncloak
# uncloak
# uncloak
# incise
# incise
# incise
# incise
# incise
# incise
# bitartrate
# bitartrate
# bitartrate
# bitartrate
# lopper
# lopper
# lopper
# exceptionable
# exceptionable
# exceptionable
# exceptionable
# expatiate
# expatiate
# expatiate
# expatiate
# expatiate
# expatiate
# expatiate
# expatiate
# expatiate
# expatiate
# expatiate
# rheometer
# rheometer
# rheometer
# rheometer
# sedulous
# sedulous
# sedulous
# sedulous
# sedulous
# miry
# miry
# miry
# miry
# reticule
# reticule
# reticule
# reticule
# reticule
# pubes
# pubes
# pubes
# pubes
# pubes
# pubes
# volatilize
# volatilize
# volatilize
# volatilize
# volatilize
# ulcerous
# ulcerous
# ulcerous
# ulcerous
# ulcerous
# inconsideration
# inconsideration
# inconsideration
# demureness
# demureness
# demureness
# demureness
# demureness
# putrescence
# putrescence
# putrescence
# putrescence
# scup
# scup
# scup
# scup
# capacitate
# capacitate
# capacitate
# capacitate
# capacitate
# capacitate
# utterer
# utterer
# utterer
# utterer
# utterer
# utterer
# utterer
# orotund
# orotund
# orotund
# orotund
# despondence
# despondence
# monarchal
# monarchal
# monarchal
# monarchal
# monarchal
# monarchal
# monarchal
# lepidolite
# lepidolite
# cosset
# cosset
# cosset
# cosset
# defrauder
# defrauder
# exostosis
# exostosis
# exostosis
# exostosis
# filthiness
# filthiness
# filthiness
# filthiness
# filthiness
# filthiness
# filthiness
# filthiness
# filthiness
# slue
# slue
# slue
# slue
# slue
# slue
# slue
# slue
# slue
# slue
# dasheen
# dasheen
# dasheen
# dasheen
# dasheen
# poltroon
# poltroon
# poltroon
# poltroon
# poltroon
# poltroon
# poltroon
# poltroon
# poltroon
# poltroon
# skidder
# skidder
# skidder
# skidder
# skidder
# pessary
# pessary
# pessary
# pessary
# acidulous
# acidulous
# acidulous
# sluggard
# sluggard
# sluggard
# sluggard
# sluggard
# percipient
# percipient
# percipient
# percipient
# primness
# primness
# primness
# primness
# particularize
# particularize
# particularize
# particularize
# particularize
# particularize
# particularize
# particularize
# prescript
# prescript
# prescript
# prescript
# prescript
# prescript
# cognize
# cognize
# cognize
# cognize
# brainpan
# brainpan
# brainpan
# brainpan
# gallimaufry
# gallimaufry
# gallimaufry
# ovalbumin
# ovalbumin
# ovalbumin
# ovalbumin
# wonted
# wonted
# wonted
# wonted
# wonted
# proctitis
# proctitis
# proctitis
# offerer
# offerer
# offerer
# offerer
# offerer
# offerer
# dreg
# dreg
# dreg
# dreg
# dreg
# dreg
# unwarrantable
# unwarrantable
# unwarrantable
# unwarrantable
# unwarrantable
# controvert
# controvert
# controvert
# controvert
# controvert
# controvert
# controvert
# deceptiveness
# deceptiveness
# deceptiveness
# steaminess
# steaminess
# micturition
# micturition
# micturition
# micturition
# inexplicit
# inexplicit
# inexplicit
# inexplicit
# inexplicit
# inexplicit
# agilely
# agilely
# agilely
# agilely
# hinderance
# hinderance
# hinderance
# hinderance
# thumbscrew
# thumbscrew
# thumbscrew
# sluiceway
# sluiceway
# inkstand
# inkstand
# inkstand
# inkstand
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# moil
# froward
# froward
# froward
# froward
# nascency
# nascency
# nascency
# nascency
# nascency
# unbacked
# unbacked
# illimitable
# illimitable
# illimitable
# illimitable
# illimitable
# countermine
# countermine
# countermine
# countermine
# countermine
# countermine
# palpitate
# palpitate
# palpitate
# palpitate
# palpitate
# palpitate
# palpitate
# palpitate
# atonic
# atonic
# atonic
# atonic
# atonic
# atonic
# effervesce
# effervesce
# effervesce
# effervesce
# slackly
# slackly
# slackly
# concuss
# concuss
# concuss
# concuss
# concuss
# concuss
# magisterially
# magisterially
# magisterially
# cerumen
# corrigendum
# corrigendum
# corrigendum
# corrigendum
# dawdler
# dawdler
# dawdler
# dawdler
# dawdler
# expectoration
# expectoration
# expectoration
# expectoration
# concupiscent
# concupiscent
# concupiscent
# concupiscent
# concupiscent
# concupiscent
# exculpation
# exculpation
# exculpation
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# pestiferous
# spellbind
# spellbind
# spellbind
# spellbind
# spellbind
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# disunite
# bestowment
# bestowment
# bestowment
# bestowment
# bestowment
# glary
# glary
# glary
# glary
# glary
# glary
# puniness
# puniness
# puniness
# puniness
# puniness
# puniness
# purblind
# purblind
# purblind
# purblind
# fourscore
# fourscore
# fourscore
# fourscore
# fourscore
# fourscore
# desiccate
# desiccate
# desiccate
# desiccate
# desiccate
# desiccate
# desiccate
# desiccate
# desiccate
# lithesome
# lithesome
# lithesome
# lithesome
# lithesome
# lithesome
# lithesome
# bosomed
# bosomed
# bosomed
# bosomed
# bosomed
# bosomed
# bosomed
# bosomed
# curiousness
# curiousness
# curiousness
# curiousness
# curiousness
# curiousness
# curiousness
# disenchant
# disenchant
# disenchant
# disenchant
# disenchant
# carious
# carious
# carious
# designedly
# designedly
# designedly
# designedly
# designedly
# amendatory
# amendatory
# amendatory
# fitly
# fitly
# fitly
# fitly
# fitly
# assimilable
# assimilable
# assimilable
# premeditate
# premeditate
# premeditate
# premeditate
# premeditate
# taciturnity
# taciturnity
# taciturnity
# assumptive
# assumptive
# assumptive
# assumptive
# assumptive
# superannuate
# superannuate
# superannuate
# superannuate
# superannuate
# arrogation
# arrogation
# arrogation
# tickseed
# tickseed
# tickseed
# tickseed
# consolidative
# consolidative
# consolidative
# consolidative
# slimly
# slimly
# slimly
# moldboard
# moldboard
# moldboard
# ravishment
# ravishment
# ravishment
# ravishment
# ravishment
# ravishment
# ravishment
# ravishment
# ravishment
# blandishment
# blandishment
# blandishment
# blandishment
# blandishment
# blandishment
# jocose
# jocose
# jocose
# jocose
# jocose
# jocose
# sponger
# sponger
# sponger
# sponger
# sponger
# aliment
# aliment
# aliment
# aliment
# aliment
# aliment
# aliment
# aliment
# aliment
# promptitude
# promptitude
# promptitude
# promptitude
# phantasmal
# phantasmal
# phantasmal
# phantasmal
# enamor
# enamor
# enamor
# enamor
# enamor
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# disport
# unvalued
# unvalued
# unvalued
# unvalued
# unvalued
# coexistent
# coexistent
# gradualness
# gradualness
# gradualness
# gradualness
# gradualness
# verruca
# verruca
# verruca
# verruca
# gayly
# gayly
# gayly
# gayly
# gayly
# gayly
# supplicate
# supplicate
# supplicate
# supplicate
# supplicate
# supplicate
# supplicate
# supplicate
# supplicate
# supplicate
# flagitious
# flagitious
# flagitious
# flagitious
# flagitious
# flagitious
# flagitious
# flagitious
# flagitious
# moonfish
# moonfish
# moonfish
# moonfish
# thirstily
# thirstily
# thirstily
# thirstily
# livelong
# livelong
# livelong
# livelong
# livelong
# ineffectualness
# ineffectualness
# ineffectualness
# slanderer
# slanderer
# woefulness
# woefulness
# woefulness
# woefulness
# lengthiness
# lengthiness
# lengthiness
# lengthiness
# numerate
# numerate
# numerate
# numerate
# cocklebur
# cocklebur
# cottager
# cottager
# cottager
# sauciness
# sauciness
# sauciness
# sauciness
# sauciness
# sauciness
# putrescible
# putrescible
# putrescible
# putrescible
# tilter
# tilter
# tilter
# tilter
# unbind
# unbind
# unbind
# unbind
# unbind
# unbind
# armhole
# armhole
# armhole
# armhole
# surcease
# surcease
# surcease
# surcease
# reship
# reship
# reship
# reship
# reship
# denseness
# denseness
# denseness
# denseness
# denseness
# imbrication
# imbrication
# imbrication
# imbrication
# fractionate
# fractionate
# fractionate
# colligate
# colligate
# colligate
# colligate
# colligate
# tailboard
# tailboard
# tailboard
# pitchy
# pitchy
# pitchy
# pitchy
# pitchy
# pitchy
# pitchy
# pitchy
# littleness
# littleness
# littleness
# littleness
# hopple
# hopple
# hopple
# hopple
# hopple
# hopple
# hopple
# ostensive
# ostensive
# ostensive
# ostensive
# ostensive
# substantiality
# substantiality
# substantiality
# chivalrously
# chivalrously
# chivalrously
# chivalrously
# outride
# outride
# outride
# outride
# subserve
# subserve
# subserve
# subserve
# subserve
# subserve
# protraction
# protraction
# protraction
# protraction
# protraction
# protraction
# protraction
# protraction
# protraction
# beastliness
# beastliness
# beastliness
# beastliness
# unloose
# unloose
# unloose
# unloose
# unloose
# unloose
# unloose
# velvetleaf
# velvetleaf
# velvetleaf
# velvetleaf
# strangulate
# strangulate
# strangulate
# scrutinizer
# scrutinizer
# cragged
# cragged
# cragged
# cragged
# cragged
# contumely
# contumely
# contumely
# contumely
# contumely
# dilatoriness
# dilatoriness
# dilatoriness
# dilatoriness
# dilatoriness
# dilatoriness
# mixable
# mixable
# capillarity
# capillarity
# capillarity
# capillarity
# sermonize
# sermonize
# sermonize
# interpenetrate
# interpenetrate
# interpenetrate
# interpenetrate
# interpenetrate
# interpenetrate
# voidance
# voidance
# voidance
# voidance
# voidance
# excrescence
# excrescence
# excrescence
# excrescence
# excrescence
# scintillate
# scintillate
# scintillate
# scintillate
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# plenteous
# leucocyte
# leucocyte
# leucocyte
# depilation
# depilation
# depilation
# unlace
# unlace
# unlace
# unlace
# unlace
# unlace
# unlace
# overspread
# overspread
# overspread
# overspread
# infeasibility
# infeasibility
# infeasibility
# accessary
# accessary
# accessary
# accessary
# accessary
# accessary
# accessary
# assort
# assort
# assort
# assort
# assort
# assort
# assort
# assort
# assort
# assort
# assort
# traduce
# traduce
# traduce
# traduce
# traduce
# traduce
# untwist
# untwist
# untwist
# untwist
# untwist
# untwist
# betoken
# betoken
# betoken
# betoken
# betoken
# betoken
# guileful
# guileful
# guileful
# guileful
# misconceive
# misconceive
# misconceive
# misconceive
# misconceive
# misconceive
# misconceive
# antedate
# antedate
# antedate
# antedate
# antedate
# antedate
# antedate
# antedate
# antedate
# antedate
# styptic
# styptic
# styptic
# styptic
# styptic
# styptic
# eelpout
# eelpout
# eelpout
# eelpout
# tachymeter
# tachymeter
# tachymeter
# rubicund
# rubicund
# rubicund
# rubicund
# intemperately
# intemperately
# intemperately
# intemperately
# intemperately
# drowse
# drowse
# drowse
# drowse
# drowse
# drowse
# drowse
# drowse
# drowse
# drowse
# sufferable
# sufferable
# sufferable
# sufferable
# resplendence
# resplendence
# resplendence
# resplendence
# resplendence
# pricker
# pricker
# pricker
# pricker
# pricker
# pricker
# pricker
# pricker
# pricker
# neckband
# neckband
# neckband
# neckband
# neckband
# accomplishable
# accomplishable
# accomplishable
# accomplishable
# solarize
# solarize
# solarize
# solarize
# enervate
# enervate
# enervate
# enervate
# enervate
# enervate
# enervate
# enervate
# enervate
# thimbleberry
# thimbleberry
# thimbleberry
# thimbleberry
# barratry
# barratry
# barratry
# barratry
# barratry
# signalize
# signalize
# signalize
# signalize
# signalize
# signalize
# signalize
# signalize
# intensiveness
# intensiveness
# intensiveness
# intensiveness
# foully
# foully
# foully
# foully
# foully
# foully
# overhasty
# overhasty
# overhasty
# overhasty
# induration
# induration
# induration
# induration
# induration
# induration
# induration
# refection
# refection
# refection
# refection
# flashily
# flashily
# flashily
# flashily
# ascribable
# ascribable
# ascribable
# lachrymal
# lachrymal
# lachrymal
# lachrymal
# effluvium
# effluvium
# effluvium
# effluvium
# courageousness
# courageousness
# courageousness
# intermittence
# intermittence
# intermittence
# intermittence
# masquerader
# masquerader
# masquerader
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# vesture
# medicament
# medicament
# medicament
# medicament
# misspend
# misspend
# misspend
# misspend
# misspend
# incombustible
# incombustible
# incombustible
# beggarly
# beggarly
# beggarly
# beggarly
# beggarly
# beggarly
# beggarly
# beggarly
# beggarly
# beggarly
# beggarly
# befool
# befool
# befool
# befool
# befool
# befool
# befool
# stogy
# stogy
# stogy
# stogy
# stogy
# stogy
# nates
# nates
# nates
# nates
# befoul
# befoul
# befoul
# befoul
# intellection
# intellection
# intellection
# intellection
# intellection
# intellection
# megrim
# megrim
# megrim
# megrim
# megrim
# megrim
# megrim
# megrim
# megrim
# megrim
# megrim
# excruciation
# excruciation
# excruciation
# minuteness
# minuteness
# minuteness
# minuteness
# exhilarate
# exhilarate
# exhilarate
# exhilarate
# exhilarate
# exhilarate
# haymow
# haymow
# haymow
# haymow
# yellowness
# yellowness
# necessitous
# necessitous
# necessitous
# necessitous
# necessitous
# necessitous
# necessitous
# consubstantial
# consubstantial
# consubstantial
# globefish
# globefish
# fibril
# fibril
# fibril
# fibril
# towrope
# towrope
# planarian
# planarian
# bereave
# bereave
# bereave
# bereave
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# wideness
# mesothelium
# mesothelium
# mesothelium
# submerse
# submerse
# submerse
# submerse
# comfortless
# comfortless
# comfortless
# comfortless
# spume
# spume
# spume
# spume
# spume
# spume
# spume
# spume
# perspicuity
# perspicuity
# perspicuity
# perspicuity
# perspicuity
# endue
# endue
# endue
# ratter
# ratter
# ratter
# ratter
# ratter
# ratter
# numskull
# numskull
# numskull
# numskull
# numskull
# lengthways
# lengthways
# lengthways
# lengthways
# lengthways
# quiddity
# quiddity
# quiddity
# quiddity
# quiddity
# quiddity
# irritative
# irritative
# irritative
# irritative
# plication
# plication
# plication
# plication
# amort
# amort
# amort
# amort
# amort
# amort
# refulgent
# refulgent
# refulgent
# refulgent
# refulgent
# refulgent
# refulgent
# forebode
# forebode
# forebode
# forebode
# forebode
# forebode
# forebode
# forebode
# mettlesome
# mettlesome
# mettlesome
# mettlesome
# mettlesome
# superabundant
# superabundant
# superabundant
# superabundant
# spicule
# spicule
# ramify
# ramify
# ramify
# ramify
# ramify
# ramify
# wheresoever
# wheresoever
# injuriously
# injuriously
# injuriously
# quadruplicate
# quadruplicate
# quadruplicate
# quadruplicate
# quadruplicate
# quadruplicate
# quadruplicate
# quadruplicate
# quadruplicate
# quadruplicate
# motorize
# motorize
# motorize
# motorize
# motorize
# braw
# braw
# braw
# braw
# braw
# braw
# braw
# enrapture
# enrapture
# enrapture
# crossly
# crossly
# crossly
# crossly
# crossly
# crossly
# gewgaw
# gewgaw
# gewgaw
# gewgaw
# gewgaw
# gewgaw
# gewgaw
# gewgaw
# resile
# resile
# resile
# resile
# resile
# resile
# resile
# inculpate
# inculpate
# inculpate
# inculpate
# inculpate
# whelm
# whelm
# whelm
# whelm
# whelm
# whelm
# whelm
# educe
# educe
# educe
# educe
# educe
# educe
# educe
# votary
# votary
# votary
# votary
# votary
# votary
# votary
# votary
# begetter
# begetter
# begetter
# assignor
# assignor
# flummery
# flummery
# flummery
# flummery
# flummery
# flummery
# flummery
# flummery
# denotative
# denotative
# denotative
# denotative
# habited
# habited
# habited
# habited
# insolvable
# insolvable
# insolvable
# insolvable
# insolvable
# insolvable
# insolvable
# carbonize
# carbonize
# carbonize
# carbonize
# aggress
# aggress
# aggress
# aggress
# aggress
# gasify
# gasify
# gasify
# gasify
# prate
# prate
# prate
# prate
# prate
# prate
# prate
# prate
# prate
# prate
# prate
# dungaree
# dungaree
# spiritualize
# spiritualize
# spiritualize
# spiritualize
# spiritualize
# spiritualize
# spiritualize
# spiritualize
# spiritualize
# osteoma
# osteoma
# osteoma
# osteoma
# insipidity
# insipidity
# insipidity
# insipidity
# insipidity
# guerdon
# guerdon
# guerdon
# guerdon
# prevaricator
# prevaricator
# prevaricator
# murkily
# murkily
# murkily
# juiceless
# juiceless
# juiceless
# juiceless
# juiceless
# asphaltic
# asphaltic
# asphaltic
# tastily
# tastily
# tastily
# tastily
# turbulently
# turbulently
# turbulently
# turbulently
# tined
# tined
# tined
# tined
# tined
# tined
# pustule
# pustule
# pustule
# sequela
# sequela
# sequela
# sequela
# sequela
# sequela
# sequela
# farseeing
# farseeing
# farseeing
# farseeing
# farseeing
# masticate
# masticate
# masticate
# masticate
# masticate
# antithetic
# antithetic
# antithetic
# antithetic
# truckle
# truckle
# truckle
# truckle
# truckle
# truckle
# truckle
# truckle
# exudation
# exudation
# exudation
# exudation
# exudation
# exudation
# stupefy
# stupefy
# stupefy
# stupefy
# stupefy
# stupefy
# stupefy
# stupefy
# demagnetize
# demagnetize
# demagnetize
# hostilely
# hostilely
# hostilely
# appose
# appose
# appose
# appose
# lissom
# lissom
# lissom
# lissom
# lissom
# lissom
# lissom
# lissom
# lissom
# safeness
# safeness
# safeness
# safeness
# safeness
# habitude
# habitude
# habitude
# habitude
# habitude
# habitude
# overfull
# overfull
# overfull
# overfull
# nonconducting
# nonconducting
# nonconducting
# blamable
# blamable
# blamable
# blamable
# blamable
# blamable
# blamable
# autogenous
# autogenous
# autogenous
# autogenous
# justificatory
# justificatory
# engrossment
# engrossment
# engrossment
# engrossment
# engrossment
# engrossment
# causeless
# causeless
# causeless
# causeless
# causeless
# causeless
# expostulation
# expostulation
# expostulation
# expostulation
# expostulation
# delusive
# delusive
# delusive
# delusive
# delusive
# delusive
# manacle
# manacle
# manacle
# manacle
# manacle
# manacle
# manacle
# manacle
# manacle
# dispirit
# dispirit
# dispirit
# dispirit
# dispirit
# dispirit
# backbite
# backbite
# backbite
# backbite
# roarer
# roarer
# roarer
# roarer
# eructation
# eructation
# eructation
# eructation
# eructation
# mendicancy
# mendicancy
# mendicancy
# mendicancy
# mendicancy
# appurtenance
# appurtenance
# appurtenance
# appurtenance
# appurtenance
# appurtenance
# appurtenance
# appurtenance
# merchantable
# merchantable
# merchantable
# merchantable
# importune
# importune
# importune
# importune
# importune
# importune
# comfit
# comfit
# comfit
# comfit
# comfit
# comfit
# hogget
# hogget
# hogget
# hogget
# ulcerate
# ulcerate
# ulcerate
# ulcerate
# ulcerate
# inculpatory
# inculpatory
# inculpatory
# bejewel
# bejewel
# bejewel
# fogginess
# fogginess
# fogginess
# ornateness
# ornateness
# ornateness
# ornateness
# ornateness
# fuddle
# fuddle
# fuddle
# fuddle
# fuddle
# fuddle
# fuddle
# fuddle
# uncaused
# uncaused
# uncaused
# uncaused
# defiler
# defiler
# defiler
# defiler
# imprecation
# imprecation
# imprecation
# imprecation
# gnarl
# gnarl
# gnarl
# gnarl
# gnarl
# gnarl
# gnarl
# slattern
# slattern
# slattern
# slattern
# slattern
# unharmonious
# unharmonious
# unharmonious
# unharmonious
# plushy
# plushy
# plushy
# plushy
# testifier
# testifier
# testifier
# testifier
# lustiness
# lustiness
# lustiness
# lustiness
# limper
# limper
# limper
# vivify
# vivify
# vivify
# vivify
# vivify
# vivify
# jounce
# jounce
# jounce
# jounce
# jounce
# jounce
# jounce
# forehanded
# forehanded
# forehanded
# forehanded
# forehanded
# forehanded
# forehanded
# forehanded
# warrantee
# warrantee
# warrantee
# warrantee
# saucily
# saucily
# saucily
# saucily
# whoredom
# whoredom
# whoredom
# whoredom
# whoredom
# fomenter
# fomenter
# fomenter
# incriminatory
# incriminatory
# understandingly
# understandingly
# understandingly
# understandingly
# aslant
# aslant
# aslant
# aslant
# aslant
# aslant
# aslant
# aslant
# dialyze
# dialyze
# dialyze
# pomology
# pomology
# pomology
# pomology
# immoderately
# immoderately
# immoderately
# immoderately
# immoderately
# flocculent
# flocculent
# flocculent
# flocculent
# mislay
# mislay
# mislay
# mislay
# mislay
# mislay
# complot
# complot
# complot
# complot
# complot
# complot
# complot
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# smatter
# inanition
# inanition
# inanition
# inanition
# inanition
# inanition
# coltsfoot
# coltsfoot
# coltsfoot
# coltsfoot
# adumbrate
# adumbrate
# adumbrate
# adumbrate
# adumbrate
# adumbrate
# adumbrate
# number of word types: 23452, number of word types w/ frequency >= 0: 23452
# 28223

# %%
assert(len(words) == len(definitions))

# %%
def create_emb_layer(weights_matrix, src_pad_token_idx, non_trainable=False):
    num_embeddings, embedding_dim = weights_matrix.shape
    emb_layer = nn.Embedding(num_embeddings, embedding_dim, src_pad_token_idx)
    emb_layer.weight.data.copy_(torch.from_numpy(weights_matrix)) #figure out what is here
    if non_trainable:
        emb_layer.weight.requires_grad = False
    return emb_layer, num_embeddings, embedding_dim

class ModelEmbeddings(nn.Module): 
    """
    Class that converts input words to their embeddings.
    """

    def __init__(self, embed_size, vocab, glove_dict):
        """
        Init the Embedding layers.

        @param embed_size (int): Embedding size (dimensionality)
        @param vocab (VocabEntry)
        """
        super(ModelEmbeddings, self).__init__()

        self.embed_size = embed_size

        matrix_len = len(vocab)
        weights_matrix = np.zeros((matrix_len, self.embed_size))
        words_found = 0
        #print(len(vocab), weights_matrix.shape)
        for word, index in vocab.word2id.items():
            try:
                weights_matrix[index] = np.array(glove_dict[word])
                words_found += 1
            except KeyError:
                weights_matrix[index] = np.random.normal(scale=0.6, size=(self.embed_size,))

        # default values
        src_pad_token_idx = vocab['<pad>']
        self.source = create_emb_layer(weights_matrix, src_pad_token_idx, False)

# %%
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, vocab, glove_dict):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = ModelEmbeddings(input_size, vocab, glove_dict)
        self.gru = nn.GRU(input_size, hidden_size)
        
        self.linear = nn.Linear(self.hidden_size, self.hidden_size, bias = True)

    def forward(self, input_, hidden, lengths , dropout_rate = 0.3):
        embedded = self.embedding.source[0](input_)
        embedded = pack_padded_sequence(embedded, lengths)
        output, hidden = self.gru(embedded, hidden)
        dropout = nn.Dropout(dropout_rate)
        hidden_dropped = dropout(hidden.permute(1,0,2)) # you dont need dropout in validation
        projected = self.linear(hidden_dropped)
        return projected, hidden

    def initHidden(self, batch_size, device = None):
        return torch.zeros(1, batch_size, self.hidden_size, device=device)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, vocab, glove_dict):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.vocab = vocab
        self.embedding = ModelEmbeddings(input_size, vocab, glove_dict)
        self.lstm = nn.LSTM(input_size, hidden_size, bidirectional = True)
        self.linear = nn.Linear(self.hidden_size * 2, self.hidden_size, bias = True)

    def forward(self, input_, hidden, lengths , dropout_rate = 0.3):
        embedded = self.embedding.source[0](input_)
        embedded = pack_padded_sequence(embedded, lengths)
        output, (h_n, c_n) = self.lstm(embedded)
        #print(h_n.shape, c_n.shape)
        dropout = nn.Dropout(dropout_rate)
        hidden_dropped = dropout(h_n.contiguous().view(1, -1, self.hidden_size * 2).permute(1,0,2)) # you dont need dropout in validation
        projected = self.linear(hidden_dropped)
        return projected, hidden

    def initHidden(self, batch_size, device = None):
        return torch.zeros(1, batch_size, self.hidden_size, device=device)

# %%
model = LSTMModel(50, 50, vocab, glove_dict)
loss_function = nn.CosineEmbeddingLoss(margin=0.0, reduction='sum')
optimizer = torch.optim.Adagrad(model.parameters(), lr = 0.1)

# %%
model = GRUModel(50, 50, vocab, glove_dict)
loss_function = nn.L1Loss(reduction = "sum")
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.999))

# %%
# #check overfit

# definition_indices = vocab.words2indices(definitions)
# words_in = 0
# words_out = 0

# import timeit
# start = timeit.default_timer()
# losses = []

# batch_size = 128

# for src_sents, tgt_word in batch_iter(training_data, batch_size, False):
#     for i in range(300):
#         model.zero_grad()
#         x_lengths = [len(sent) for sent in src_sents]
#         x = vocab.to_input_tensor(src_sents, "cpu")
#         init_hidden = model.initHidden(len(src_sents), "cpu")
#         tag_scores = model.forward(x, init_hidden, x_lengths)
#         y_array = model.embedding.source[0](torch.tensor(vocab.words2indices(tgt_word))).double()
#         y_pred = tag_scores[0].squeeze(dim = 1).double()
#         loss = loss_function(y_pred, y_array, torch.tensor(1))
#         loss.backward()
#         optimizer.step() 
#         losses.append(loss)
#         if i % 100 == 0:
#             print(i, loss)
#     break
    
# stop = timeit.default_timer()

# print('Time: ', stop - start)

# import matplotlib.pyplot as plt
# print(plt.plot([l.double() for l in losses][:1200]))

# model.zero_grad()
# x_lengths = [len(sent) for sent in src_sents]
# x = vocab.to_input_tensor(src_sents, "cpu")
# init_hidden = model.initHidden(len(src_sents), "cpu")
# tag_scores = model.forward(x, init_hidden, x_lengths)
# y_pred = tag_scores[0].squeeze(dim = 1).double()

# validate_dict = dict([(w, model.embedding.source[0](torch.tensor(vocab[w])).numpy()) for w in set(words)])
# print(len(validate_dict))

# print(y_pred.shape)
# for i in range(len(y_pred)):
#     eval.top_ten_hundred(validate_dict, tgt_word[i], y_pred[i].detach().numpy())

# %%
definition_indices = vocab.words2indices(definitions)
words_in = 0
words_out = 0

import timeit
start = timeit.default_timer()
losses = []

batch_size = 128

for epoch in range(500000):
    for src_sents, tgt_word in batch_iter(training_data, batch_size, False):
        model.zero_grad()
        x_lengths = [len(sent) for sent in src_sents]
        x = vocab.to_input_tensor(src_sents, "cpu")
        init_hidden = model.initHidden(len(src_sents), "cpu")
        tag_scores = model.forward(x, init_hidden, x_lengths)
        y_array = model.embedding.source[0](torch.tensor(vocab.words2indices(tgt_word))).double()
        y_pred = tag_scores[0].squeeze(dim = 1).double()
        loss = loss_function(y_pred, y_array, torch.tensor(1))
        loss.backward()
        optimizer.step() 
    losses.append(loss)
    print(epoch, loss, timeit.default_timer() - start)
    
stop = timeit.default_timer()

print('Time: ', stop - start)

import matplotlib.pyplot as plt
print(plt.plot([l.double() for l in losses]))
# Out:
# 0 tensor(37.0105, dtype=torch.float64, grad_fn=<SumBackward0>) 49.552044556010514
# 1 tensor(36.7953, dtype=torch.float64, grad_fn=<SumBackward0>) 98.70971733599436
# 2 tensor(36.7851, dtype=torch.float64, grad_fn=<SumBackward0>) 148.10029122105334
# 3 tensor(36.8106, dtype=torch.float64, grad_fn=<SumBackward0>) 197.1139509039931
# 4 tensor(36.6834, dtype=torch.float64, grad_fn=<SumBackward0>) 246.57386586803477
# 5 tensor(36.6038, dtype=torch.float64, grad_fn=<SumBackward0>) 295.7267740110401
# 6 tensor(36.7005, dtype=torch.float64, grad_fn=<SumBackward0>) 344.9124259450473
# 7 tensor(36.6043, dtype=torch.float64, grad_fn=<SumBackward0>) 394.13260132004507
# 8 tensor(36.6248, dtype=torch.float64, grad_fn=<SumBackward0>) 446.2513037919998
# 9 tensor(36.6493, dtype=torch.float64, grad_fn=<SumBackward0>) 495.21761862304993
# 10 tensor(36.7422, dtype=torch.float64, grad_fn=<SumBackward0>) 544.1186677459627
# 11 tensor(36.7540, dtype=torch.float64, grad_fn=<SumBackward0>) 593.589429029962
# 12 tensor(36.6129, dtype=torch.float64, grad_fn=<SumBackward0>) 644.440970637952
# 13 tensor(36.6727, dtype=torch.float64, grad_fn=<SumBackward0>) 715.180000880966
# 14 tensor(36.5089, dtype=torch.float64, grad_fn=<SumBackward0>) 789.1364589049481
# 15 tensor(36.5124, dtype=torch.float64, grad_fn=<SumBackward0>) 844.5213403550442
# 16 tensor(36.7720, dtype=torch.float64, grad_fn=<SumBackward0>) 897.8765642220387
# 17 tensor(36.5832, dtype=torch.float64, grad_fn=<SumBackward0>) 948.3496043350315
# 18 tensor(36.5560, dtype=torch.float64, grad_fn=<SumBackward0>) 1000.5400829509599
# 19 tensor(36.5254, dtype=torch.float64, grad_fn=<SumBackward0>) 1052.3894450799562
# 20 tensor(36.7000, dtype=torch.float64, grad_fn=<SumBackward0>) 1101.0898731120396
# 21 tensor(36.4000, dtype=torch.float64, grad_fn=<SumBackward0>) 1150.1295415440109
# 22 tensor(36.8503, dtype=torch.float64, grad_fn=<SumBackward0>) 1199.3002978820587
# 23 tensor(36.7709, dtype=torch.float64, grad_fn=<SumBackward0>) 1248.6049992250046
# 24 tensor(36.7967, dtype=torch.float64, grad_fn=<SumBackward0>) 1298.1934121330269
# 25 tensor(36.3684, dtype=torch.float64, grad_fn=<SumBackward0>) 1347.5930371000431
# 26 tensor(36.4574, dtype=torch.float64, grad_fn=<SumBackward0>) 1396.9020274759969
# 27 tensor(36.7419, dtype=torch.float64, grad_fn=<SumBackward0>) 1456.803202538984
# 28 tensor(36.5370, dtype=torch.float64, grad_fn=<SumBackward0>) 1512.952718787943
# 29 tensor(36.5567, dtype=torch.float64, grad_fn=<SumBackward0>) 1568.297438420006
# 30 tensor(36.6873, dtype=torch.float64, grad_fn=<SumBackward0>) 1633.8835400319658
# 31 tensor(37.0412, dtype=torch.float64, grad_fn=<SumBackward0>) 1691.00774400495
# 32 tensor(36.4425, dtype=torch.float64, grad_fn=<SumBackward0>) 1747.93518893898
# 33 tensor(36.8029, dtype=torch.float64, grad_fn=<SumBackward0>) 1805.207439786056
# 34 tensor(36.6430, dtype=torch.float64, grad_fn=<SumBackward0>) 1860.5832124300068
# 35 tensor(36.8338, dtype=torch.float64, grad_fn=<SumBackward0>) 1920.6858014300233
# 36 tensor(36.3333, dtype=torch.float64, grad_fn=<SumBackward0>) 1979.242126689991
# 37 tensor(37.0251, dtype=torch.float64, grad_fn=<SumBackward0>) 2037.9402707229601
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-24f309a56d39> in <module>
#      19         y_pred = tag_scores[0].squeeze(dim = 1).double()
#      20         loss = loss_function(y_pred, y_array, torch.tensor(1))
# ---> 21         loss.backward()
#      22         optimizer.step()
#      23     losses.append(loss)
#
# ~/opt/miniconda3/envs/local_nmt/lib/python3.5/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/opt/miniconda3/envs/local_nmt/lib/python3.5/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
print(plt.plot([l.double() for l in losses]))
# Out:
# [<matplotlib.lines.Line2D object at 0x1a37eebc50>]

# %%
model.zero_grad()
x_lengths = [len(sent) for sent in src_sents]
x = vocab.to_input_tensor(src_sents, "cpu")
init_hidden = model.initHidden(len(src_sents), "cpu")
tag_scores = model.forward(x, init_hidden, x_lengths)
y_pred = tag_scores[0].squeeze(dim = 1).double()

validate_dict = dict([(w, model.embedding.source[0](torch.tensor(vocab[w])).detach().numpy()) for w in set(words)])
print(len(validate_dict))

print(y_pred.shape)
for i in range(len(y_pred)):
    eval.top_ten_hundred(validate_dict, tgt_word[i], y_pred[i].detach().numpy())
# Out:
# 19661
# torch.Size([128, 50])
# syncopation ['lozenge', 'vaporous', 'collimator', 'pimple', 'extractor', 'protrusion', 'springy', 'rasp', 'pomade', 'vibrator']
# nozzle ['collimator', 'lozenge', 'vibrator', 'vaporous', 'extractor', 'chamfer', 'pimple', 'scraper', 'barm', 'pomade']
# gunpowder ['lozenge', 'collimator', 'scraper', 'extractor', 'vibrator', 'protrusion', 'tumbler', 'dumbbell', 'diaphragm', 'receptacle']
# apostolic ['simple', 'sort', 'pattern', 'meaning', 'characteristic', 'fluid', 'insertion', 'form', 'rather', 'attachment']
# gunpowder ['diaphragm', 'insertion', 'fluid', 'crutch', 'sticky', 'elastic', 'cavity', 'protrusion', 'suction', 'horizontal']
# chestnut ['instead', 'turn', 'same', 'use', 'making', 'rather', 'full', 'form', 'well', 'small']
# apostolic ['lozenge', 'protrusion', 'proverbial', 'crutch', 'diaphragm', 'appendage', 'collimator', 'feathery', 'stringy', 'scrotum']
# apostolic ['rather', 'simple', 'form', 'sort', 'sometimes', 'kind', 'instead', 'shape', 'meaning', 'combination']
# syncopation ['rather', 'sort', 'kind', 'simple', 'sometimes', 'form', 'meaning', 'merely', 'instead', 'often']
# caterpillar ['crutch', 'insertion', 'diaphragm', 'protrusion', 'proverbial', 'metaphoric', 'scrotum', 'adjectival', 'attachment', 'collimator']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-6caf7f0090f8> in <module>
#      11 print(y_pred.shape)
#      12 for i in range(len(y_pred)):
# ---> 13     eval.top_ten_hundred(validate_dict, tgt_word[i], y_pred[i].detach().numpy())
#
# ~/Development/Dict2Word/model/evaluator.py in top_ten_hundred(self, embeddings_dict, answer, guess)
#      44         """
#      45         self.th_tracker['count'] += 1
# ---> 46         top_hundred = self.find_closest_embeddings(embeddings_dict, guess, k = 100)
#      47         top_ten = top_hundred[:10]
#      48         if answer in top_ten:
#
# ~/Development/Dict2Word/model/evaluator.py in find_closest_embeddings(self, embeddings_dict, embedding, k)
#      33         """
#      34         ans = sorted(embeddings_dict.keys(),
# ---> 35                       key=lambda word: spatial.distance.cosine(embeddings_dict[word], embedding))
#      36
#      37         return ans[:k]
#
# ~/Development/Dict2Word/model/evaluator.py in <lambda>(word)
#      33         """
#      34         ans = sorted(embeddings_dict.keys(),
# ---> 35                       key=lambda word: spatial.distance.cosine(embeddings_dict[word], embedding))
#      36
#      37         return ans[:k]
#
# ~/opt/miniconda3/envs/local_nmt/lib/python3.5/site-packages/scipy/spatial/distance.py in cosine(u, v, w)
#     742     # cosine distance is also referred to as 'uncentered correlation',
#     743     #   or 'reflective correlation'
# --> 744     return correlation(u, v, w=w, centered=False)
#     745
#     746
#
# ~/opt/miniconda3/envs/local_nmt/lib/python3.5/site-packages/scipy/spatial/distance.py in correlation(u, v, w, centered)
#     693         u = u - umu
#     694         v = v - vmu
# --> 695     uv = np.average(u * v, weights=w)
#     696     uu = np.average(np.square(u), weights=w)
#     697     vv = np.average(np.square(v), weights=w)
#
# KeyboardInterrupt:
